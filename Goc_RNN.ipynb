# %% [markdown]
# # Import thư viện

# %%
import cv2
from skimage.feature import hog
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import GRU, Dense, Dropout, Input, SimpleRNN, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Đọc và xử lý dữ liệu số

# %%
def read_data_number(data_path, time_col="thoi_gian"):
    # Đọc dữ liệu từ file CSV
    data = pd.read_csv(data_path)
    
    # Chuyển đổi cột thời gian sang kiểu datetime và đặt làm index
    data[time_col] = pd.to_datetime(data[time_col])
    data.set_index(time_col, inplace=True)
    
    # Tái lấy mẫu và tính toán thống kê
    y_t = data[['Mực nước hồ (m)', 'Lưu lượng đến hồ (m³/s)']].resample("D").mean()
    
    return y_t

# %%
def create_dataframe(y_t, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2"):
    df = pd.DataFrame({time_col: y_t.index, 
                       value_col_1: y_t['Mực nước hồ (m)'].values, 
                       value_col_2: y_t['Lưu lượng đến hồ (m³/s)'].values})
    return df

# %% [markdown]
# # Áp dụng LSTM để dự đoán

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = df[['y_t_1', 'y_t_2']]
    y = df[['y_t_1']]

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler_X, scaler_y, X_data, y_data

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước X_train:", X_train.shape)
    print("Kích thước X_val:", X_val.shape)
    print("Kích thước X_test:", X_test.shape)
    print("Kích thước y_train:", y_train.shape)
    print("Kích thước y_val:", y_val.shape)
    print("Kích thước y_test:", y_test.shape)

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# ### Xây dựng mô hình LSTM

# %%
def train_model(X_train, y_train, X_val, y_val, epochs, batch_size, save_best_model):
    # Xác định kích thước đầu vào
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
    
    # Xây dựng mô hình GRU
    x = SimpleRNN(32, activation='tanh', return_sequences=False)(input_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    # Fully Connected Layer
    output_layer = Dense(1, activation='sigmoid')(x)  # Sử dụng 'sigmoid' nếu đầu ra nằm trong [0,1]
    
    # Khởi tạo model
    model = Model(inputs=input_layer, outputs=output_layer)
    
    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=1e-3), loss='mean_squared_error')
    
    # Callback lưu model tốt nhất
    model_checkpoint = ModelCheckpoint(save_best_model, save_best_only=True, monitor='val_loss', mode='min', verbose=1)
    
    # Train mô hình
    history = model.fit(X_train, y_train, 
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=[model_checkpoint])
    
    return model, history

# %% [markdown]
# ### Đánh giá mô hình

# %%
# Xác định điểm bất thường
def evaluate_outside_confidence(y_test, y_true, alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_test
    mean_yt = np.mean(y_test)
    std_yt = np.std(y_test, ddof=1)  # ddof=1 để tính std của mẫu

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_test)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_test)))

    # Xác định các index mà y_test nằm ngoài khoảng tin cậy
    outside_ci_indices = np.where((y_test < ci_lower) | (y_test > ci_upper))[0]

    # Truy xuất dữ liệu đúng cách
    y_t_outside = y_test.iloc[outside_ci_indices]
    y_true_outside = y_true.iloc[outside_ci_indices]

    return y_t_outside, y_true_outside

# %%
def evaluate_metrics(y_true, y_pred):
    # Chuyển về numpy array 1D để mọi phép tính sum đều cho ra scalar
    y_true_arr = np.ravel(y_true)
    y_pred_arr = np.ravel(y_pred)

    mae = round(mean_absolute_error(y_true_arr, y_pred_arr), 6)
    mse = round(mean_squared_error(y_true_arr, y_pred_arr), 6)
    rmse = round(np.sqrt(mse), 6)
    
    # Tính sai số dự báo
    errors = y_true_arr - y_pred_arr
    
    # Tracking Signal: TS = Tổng sai số dự báo tích lũy / Tổng độ lệch tuyệt đối của sai số
    tracking_signal = np.sum(errors) / np.sum(np.abs(errors))
    tracking_signal = round(tracking_signal, 6)
    
    # NSE (Nash–Sutcliffe Efficiency):
    # NSE = 1 - [ sum((y_true - y_pred)^2) / sum((y_true - mean(y_true))^2 ) ]
    numerator   = np.sum((y_true_arr - y_pred_arr) ** 2)
    denominator = np.sum((y_true_arr - np.mean(y_true_arr)) ** 2)
    
    # Sau khi ravel, denominator là float; chỉ cần so sánh bình thường
    if denominator == 0:
        nse = np.nan
    else:
        nse = 1 - numerator / denominator
        nse = round(nse, 6)
    
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "Tracking Signal": tracking_signal,
        "NSE": nse
    }

# %% [markdown]
# ### Dự báo và trực quan

# %%
# Trực quan hóa dữ liệu dự báo không dùng index
def plot_forecast(y_true, y_pred, title="Lake level forecast", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_true
    mean_yt = np.mean(y_true)
    std_yt = np.std(y_true, ddof=1)

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_true)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_true)))

    # Tạo trục x là các chỉ mục tuần tự
    x = np.arange(len(y_true))

    # Vẽ biểu đồ
    plt.figure(figsize=(10, 5))

    # Vẽ dữ liệu thực tế
    plt.plot(x, y_true, label="Actual value", color="blue", linestyle='-', alpha=0.7)

    # Vẽ dự báo
    plt.plot(x, y_pred, label="Predicted value", color="red", linestyle='--', alpha=0.7)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(x, ci_lower, ci_upper, color='gray', alpha=0.3, label='99.9% CI')

    # Thiết lập tiêu đề và nhãn
    plt.title(title)
    plt.xlabel("Time Steps")
    plt.ylabel("Water Level (m)")
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.5)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Thực hiện từng phần

# %% [markdown]
# ### Tiền xử lý dữ liệu số

# %%
# Đọc dữ liệu đầu vào
path_data = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\KaNak.csv"
data = read_data_number(path_data, time_col="thoi_gian")

# Tạo DataFrame chứa thời gian và mực nước
y_t = create_dataframe(data, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2")

# %% [markdown]
# ### Chia dữ liệu

# %%
time_steps = 7

scaler_X, scaler_y, X_data, y_data = scaler(y_t, time_steps)
# X_data, y_data = scaler_v1(df_ts, time_steps)

X_train, y_train, X_val, y_val, X_test, y_test = split_data(X_data, y_data, time_steps)
# Out:
# Kích thước X_train: (1017, 7, 2)
# Kích thước X_val: (218, 7, 2)
# Kích thước X_test: (218, 7, 2)
# Kích thước y_train: (1017, 1)
# Kích thước y_val: (218, 1)
# Kích thước y_test: (218, 1)

# %% [markdown]
# ### Huấn luyện ARIMA

# %%
model, history = train_model(X_train, y_train,
                             X_val, y_val,
                             epochs=200,
                             batch_size=16,
                             save_best_model='./BestModel/best_model_goc_RNN_KN.hdf5')
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 38/64 [================>.............] - ETA: 0s - loss: 0.0494
# Epoch 1: val_loss improved from inf to 0.08776, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 1s 5ms/step - loss: 0.0371 - val_loss: 0.0878
# Epoch 2/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0212
# Epoch 2: val_loss did not improve from 0.08776
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.1082
# Epoch 3/200
# 28/64 [============>.................] - ETA: 0s - loss: 0.0156
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 47/64 [=====================>........] - ETA: 0s - loss: 0.0185
# Epoch 3: val_loss did not improve from 0.08776
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.1017
# Epoch 4/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0153
# Epoch 4: val_loss improved from 0.08776 to 0.07065, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0707
# Epoch 5/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0139
# Epoch 5: val_loss improved from 0.07065 to 0.04939, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0494
# Epoch 6/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0136
# Epoch 6: val_loss did not improve from 0.04939
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0606
# Epoch 7/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0184
# Epoch 7: val_loss did not improve from 0.04939
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0515
# Epoch 8/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0143
# Epoch 8: val_loss improved from 0.04939 to 0.02908, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0291
# Epoch 9/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0102
# Epoch 9: val_loss improved from 0.02908 to 0.01435, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0143
# Epoch 10/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0098
# Epoch 10: val_loss improved from 0.01435 to 0.00637, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0064
# Epoch 11/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0086
# Epoch 11: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 12/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0081
# Epoch 12: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0152
# Epoch 13/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0083
# Epoch 13: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0163
# Epoch 14/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0069
# Epoch 14: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0105
# Epoch 15/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0087
# Epoch 15: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0142
# Epoch 16/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0093
# Epoch 16: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0160
# Epoch 17/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0066
# Epoch 17: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0144
# Epoch 18/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0067
# Epoch 18: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 19/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0073
# Epoch 19: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 20/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0059
# Epoch 20: val_loss did not improve from 0.00637
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0075
# Epoch 21/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0068
# Epoch 21: val_loss improved from 0.00637 to 0.00395, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0040
# Epoch 22/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0060
# Epoch 22: val_loss did not improve from 0.00395
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 23/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0072
# Epoch 23: val_loss did not improve from 0.00395
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 24/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0062
# Epoch 24: val_loss did not improve from 0.00395
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0101
# Epoch 25/200
# 49/64 [=====================>........] - ETA: 0s - loss: 0.0076
# Epoch 25: val_loss did not improve from 0.00395
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 26/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0061
# Epoch 26: val_loss improved from 0.00395 to 0.00247, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0025
# Epoch 27/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0060
# Epoch 27: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0084
# Epoch 28/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0073
# Epoch 28: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0057
# Epoch 29/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0070
# Epoch 29: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 30/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0050
# Epoch 30: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 31/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0062
# Epoch 31: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 32/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0077
# Epoch 32: val_loss did not improve from 0.00247
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0110
# Epoch 33/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0069
# Epoch 33: val_loss improved from 0.00247 to 0.00151, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0015
# Epoch 34/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0066
# Epoch 34: val_loss did not improve from 0.00151
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0020
# Epoch 35/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0058
# Epoch 35: val_loss improved from 0.00151 to 0.00139, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 36/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0055
# Epoch 36: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 37/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0071
# Epoch 37: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0078
# Epoch 38/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0064
# Epoch 38: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0103
# Epoch 39/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0057
# Epoch 39: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0119
# Epoch 40/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0053
# Epoch 40: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 41/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0067
# Epoch 41: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 42/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0061
# Epoch 42: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 43/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0069
# Epoch 43: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0038
# Epoch 44/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0076
# Epoch 44: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 45/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0043
# Epoch 45: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 46/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0053
# Epoch 46: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0044
# Epoch 47/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0055
# Epoch 47: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 48/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0072
# Epoch 48: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 49/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0065
# Epoch 49: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 50/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0066
# Epoch 50: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0022
# Epoch 51/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0056
# Epoch 51: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 52/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0045
# Epoch 52: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0109
# Epoch 53/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0052
# Epoch 53: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0086
# Epoch 54/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0073
# Epoch 54: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0026
# Epoch 55/200
# 31/64 [=============>................] - ETA: 0s - loss: 0.0056
# Epoch 55: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 56/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0075
# Epoch 56: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 57/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0065
# Epoch 57: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 58/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0063
# Epoch 58: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0024
# Epoch 59/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0060
# Epoch 59: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 60/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0065
# Epoch 60: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 61/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0059
# Epoch 61: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0017
# Epoch 62/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0066
# Epoch 62: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 63/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0067
# Epoch 63: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 64/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0050
# Epoch 64: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 65/200
# 31/64 [=============>................] - ETA: 0s - loss: 0.0054
# Epoch 65: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0020
# Epoch 66/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0070
# Epoch 66: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0160
# Epoch 67/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0069
# Epoch 67: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0080
# Epoch 68/200
# 31/64 [=============>................] - ETA: 0s - loss: 0.0075
# Epoch 68: val_loss did not improve from 0.00139
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 69/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0054
# Epoch 69: val_loss improved from 0.00139 to 0.00137, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0014
# Epoch 70/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0050
# Epoch 70: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 71/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0067
# Epoch 71: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 72/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0064
# Epoch 72: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 73/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0069
# Epoch 73: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 74/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0052
# Epoch 74: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0017
# Epoch 75/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0065
# Epoch 75: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 76/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0066
# Epoch 76: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0086
# Epoch 77/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0064
# Epoch 77: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0099
# Epoch 78/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0072
# Epoch 78: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0052
# Epoch 79/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0061
# Epoch 79: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 80/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0060
# Epoch 80: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0039
# Epoch 81/200
# 50/64 [======================>.......] - ETA: 0s - loss: 0.0066
# Epoch 81: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0100
# Epoch 82/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0070
# Epoch 82: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0169
# Epoch 83/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0048
# Epoch 83: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0077
# Epoch 84/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0069
# Epoch 84: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0033
# Epoch 85/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0059
# Epoch 85: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0172
# Epoch 86/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0044
# Epoch 86: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 87/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0056
# Epoch 87: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 88/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0063
# Epoch 88: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0209
# Epoch 89/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0050
# Epoch 89: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 90/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0055
# Epoch 90: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 91/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0053
# Epoch 91: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0082
# Epoch 92/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0051
# Epoch 92: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0173
# Epoch 93/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0057
# Epoch 93: val_loss did not improve from 0.00137
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0084
# Epoch 94/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0056
# Epoch 94: val_loss improved from 0.00137 to 0.00136, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 95/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0050
# Epoch 95: val_loss did not improve from 0.00136
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 96/200
# 31/64 [=============>................] - ETA: 0s - loss: 0.0058
# Epoch 96: val_loss did not improve from 0.00136
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0125
# Epoch 97/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 97: val_loss improved from 0.00136 to 0.00135, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 98/200
# 31/64 [=============>................] - ETA: 0s - loss: 0.0059
# Epoch 98: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0301
# Epoch 99/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0062
# Epoch 99: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0017
# Epoch 100/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0051
# Epoch 100: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0024
# Epoch 101/200
# 28/64 [============>.................] - ETA: 0s - loss: 0.0051
# Epoch 101: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 102/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0073
# Epoch 102: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 103/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0051
# Epoch 103: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 104/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0069
# Epoch 104: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0611
# Epoch 105/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0061
# Epoch 105: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 106/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0059
# Epoch 106: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0087
# Epoch 107/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0062
# Epoch 107: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0023
# Epoch 108/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0056
# Epoch 108: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0094
# Epoch 109/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0061
# Epoch 109: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 110/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0039
# Epoch 110: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0029
# Epoch 111/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0050
# Epoch 111: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 112/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0053
# Epoch 112: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0152
# Epoch 113/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0061
# Epoch 113: val_loss did not improve from 0.00135
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0199
# Epoch 114/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0064
# Epoch 114: val_loss improved from 0.00135 to 0.00111, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 115/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0055
# Epoch 115: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0024
# Epoch 116/200
# 32/64 [==============>...............] - ETA: 0s - loss: 0.0061
# Epoch 116: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 117/200
# 32/64 [==============>...............] - ETA: 0s - loss: 0.0080
# Epoch 117: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0024
# Epoch 118/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0062
# Epoch 118: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0016
# Epoch 119/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0055
# Epoch 119: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 120/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0061
# Epoch 120: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0017
# Epoch 121/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0059
# Epoch 121: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 122/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0062
# Epoch 122: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 123/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0054
# Epoch 123: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0122
# Epoch 124/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0057
# Epoch 124: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0126
# Epoch 125/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0057
# Epoch 125: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 126/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0067
# Epoch 126: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0400
# Epoch 127/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0053
# Epoch 127: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0152
# Epoch 128/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0060
# Epoch 128: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0047
# Epoch 129/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0060
# Epoch 129: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 130/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0055
# Epoch 130: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0044
# Epoch 131/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0050
# Epoch 131: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 132/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0053
# Epoch 132: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 133/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0066
# Epoch 133: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 134/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0071
# Epoch 134: val_loss did not improve from 0.00111
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 135/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0053
# Epoch 135: val_loss improved from 0.00111 to 0.00094, saving model to ./BestModel\best_model_goc_RNN_KN.hdf5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 9.4017e-04
# Epoch 136/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0069
# Epoch 136: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0193
# Epoch 137/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0059
# Epoch 137: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 138/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0050
# Epoch 138: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0306
# Epoch 139/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 139: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 140/200
# 33/64 [==============>...............] - ETA: 0s - loss: 0.0076
# Epoch 140: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 141/200
# 32/64 [==============>...............] - ETA: 0s - loss: 0.0058
# Epoch 141: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0155
# Epoch 142/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0044
# Epoch 142: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0030
# Epoch 143/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0064
# Epoch 143: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 144/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0066
# Epoch 144: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 145/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0049
# Epoch 145: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0101
# Epoch 146/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0067
# Epoch 146: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 147/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0049
# Epoch 147: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0129
# Epoch 148/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0071
# Epoch 148: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 149/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0063
# Epoch 149: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0236
# Epoch 150/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0052
# Epoch 150: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 151/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0052
# Epoch 151: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0091
# Epoch 152/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0042
# Epoch 152: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 153/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0066
# Epoch 153: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0141
# Epoch 154/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 154: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 155/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 155: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0115
# Epoch 156/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0052
# Epoch 156: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 157/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0067
# Epoch 157: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0027
# Epoch 158/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0056
# Epoch 158: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0075
# Epoch 159/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0061
# Epoch 159: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 160/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0056
# Epoch 160: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 161/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0067
# Epoch 161: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 162/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0070
# Epoch 162: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0030
# Epoch 163/200
# 35/64 [===============>..............] - ETA: 0s - loss: 0.0043
# Epoch 163: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0405
# Epoch 164/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0052
# Epoch 164: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0131
# Epoch 165/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0054
# Epoch 165: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0132
# Epoch 166/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0063
# Epoch 166: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0029
# Epoch 167/200
# 34/64 [==============>...............] - ETA: 0s - loss: 0.0050
# Epoch 167: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0409
# Epoch 168/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0059
# Epoch 168: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0022
# Epoch 169/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0054
# Epoch 169: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0037
# Epoch 170/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0052
# Epoch 170: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0328
# Epoch 171/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0051
# Epoch 171: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0010
# Epoch 172/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0064
# Epoch 172: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 173/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0054
# Epoch 173: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0196
# Epoch 174/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0070
# Epoch 174: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 175/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0055
# Epoch 175: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 176/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0067
# Epoch 176: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0110
# Epoch 177/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0048
# Epoch 177: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0160
# Epoch 178/200
# 41/64 [==================>...........] - ETA: 0s - loss: 0.0076
# Epoch 178: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 179/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0047
# Epoch 179: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0125
# Epoch 180/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0078
# Epoch 180: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 181/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0040
# Epoch 181: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0070
# Epoch 182/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0036
# Epoch 182: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0099
# Epoch 183/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0053
# Epoch 183: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0135
# Epoch 184/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0061
# Epoch 184: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0278
# Epoch 185/200
# 36/64 [===============>..............] - ETA: 0s - loss: 0.0047
# Epoch 185: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0081
# Epoch 186/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0064
# Epoch 186: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 187/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0046
# Epoch 187: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0704
# Epoch 188/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0058
# Epoch 188: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0023
# Epoch 189/200
# 37/64 [================>.............] - ETA: 0s - loss: 0.0059
# Epoch 189: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 190/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0044
# Epoch 190: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0182
# Epoch 191/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0057
# Epoch 191: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0135
# Epoch 192/200
# 40/64 [=================>............] - ETA: 0s - loss: 0.0063
# Epoch 192: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0120
# Epoch 193/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0058
# Epoch 193: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0139
# Epoch 194/200
# 38/64 [================>.............] - ETA: 0s - loss: 0.0056
# Epoch 194: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 195/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0053
# Epoch 195: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0264
# Epoch 196/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0057
# Epoch 196: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0119
# Epoch 197/200
# 39/64 [=================>............] - ETA: 0s - loss: 0.0050
# Epoch 197: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 198/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0053
# Epoch 198: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 199/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0057
# Epoch 199: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 200/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 200: val_loss did not improve from 0.00094
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0145

# %% [markdown]
# ### Đánh giá mô hình dự báo trên tập test

# %%
# Đọc model tốt nhất
from keras.models import load_model
model = load_model('./BestModel/best_model_goc_RNN_KN.hdf5')

# Dự đoán trên tập validation
y_pred = model.predict(X_test)

y_pred, y_test = inverse_transform_data(scaler_y, y_pred, y_test)

evaluate_metrics(y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 1ms/step
# {'MAE': 0.464703,
#  'MSE': 0.360064,
#  'RMSE': 0.600053,
#  'Tracking Signal': 0.019519,
#  'NSE': 0.984958}

# %%
plot_forecast(y_test, y_pred)
# Out:
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)

# Đánh giá
evaluate_metrics(y_true_out, y_t_out)
# Out:
# {'MAE': 0.441658,
#  'MSE': 0.325222,
#  'RMSE': 0.570282,
#  'Tracking Signal': -0.113583,
#  'NSE': 0.985736}
