# %% [markdown]
# # Import thư viện

# %%
import cv2
from skimage.feature import hog
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import LSTM, Dense, Dropout, Input, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Đọc và xử lý dữ liệu số

# %%
def read_data_number(data_path, time_col="thoi_gian"):
    # Đọc dữ liệu từ file CSV
    data = pd.read_csv(data_path)
    
    # Chuyển đổi cột thời gian sang kiểu datetime và đặt làm index
    data[time_col] = pd.to_datetime(data[time_col])
    data.set_index(time_col, inplace=True)
    
    # Tái lấy mẫu và tính toán thống kê
    y_t = data[['Mực nước hồ (m)', 'Lưu lượng đến hồ (m³/s)']].resample("D").mean()
    
    return y_t

# %%
def create_dataframe(y_t, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2"):
    df = pd.DataFrame({time_col: y_t.index, 
                       value_col_1: y_t['Mực nước hồ (m)'].values, 
                       value_col_2: y_t['Lưu lượng đến hồ (m³/s)'].values})
    return df

# %% [markdown]
# # Áp dụng LSTM để dự đoán

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = df[['y_t_1', 'y_t_2']]
    y = df[['y_t_1']]

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler_X, scaler_y, X_data, y_data

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước X_train:", X_train.shape)
    print("Kích thước X_val:", X_val.shape)
    print("Kích thước X_test:", X_test.shape)
    print("Kích thước y_train:", y_train.shape)
    print("Kích thước y_val:", y_val.shape)
    print("Kích thước y_test:", y_test.shape)

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# ### Xây dựng mô hình LSTM

# %%
def train_model(X_train, y_train, X_val, y_val, epochs, batch_size, save_best_model):
    # Xác định kích thước đầu vào
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
    
    # Xây dựng mô hình GRU
    x = LSTM(32, activation='tanh', return_sequences=False)(input_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Fully Connected Layer
    output_layer = Dense(1, activation='sigmoid')(x)  # Sử dụng 'sigmoid' nếu đầu ra nằm trong [0,1]
    
    # Khởi tạo model
    model = Model(inputs=input_layer, outputs=output_layer)
    
    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=1e-3), loss='mean_squared_error')
    
    # Callback lưu model tốt nhất
    model_checkpoint = ModelCheckpoint(save_best_model, save_best_only=True, monitor='val_loss', mode='min', verbose=1)
    
    # Train mô hình
    history = model.fit(X_train, y_train, 
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=[model_checkpoint])
    
    return model, history

# %% [markdown]
# ### Đánh giá mô hình

# %%
# Xác định điểm bất thường
def evaluate_outside_confidence(y_test, y_true, alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_test
    mean_yt = np.mean(y_test)
    std_yt = np.std(y_test, ddof=1)  # ddof=1 để tính std của mẫu

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_test)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_test)))

    # Xác định các index mà y_test nằm ngoài khoảng tin cậy
    outside_ci_indices = np.where((y_test < ci_lower) | (y_test > ci_upper))[0]

    # Truy xuất dữ liệu đúng cách
    y_t_outside = y_test.iloc[outside_ci_indices]
    y_true_outside = y_true.iloc[outside_ci_indices]

    return y_t_outside, y_true_outside

# %%
def evaluate_metrics(y_true, y_pred):
    # Chuyển về numpy array 1D để mọi phép tính sum đều cho ra scalar
    y_true_arr = np.ravel(y_true)
    y_pred_arr = np.ravel(y_pred)

    mae = round(mean_absolute_error(y_true_arr, y_pred_arr), 6)
    mse = round(mean_squared_error(y_true_arr, y_pred_arr), 6)
    rmse = round(np.sqrt(mse), 6)
    
    # Tính sai số dự báo
    errors = y_true_arr - y_pred_arr
    
    # Tracking Signal: TS = Tổng sai số dự báo tích lũy / Tổng độ lệch tuyệt đối của sai số
    tracking_signal = np.sum(errors) / np.sum(np.abs(errors))
    tracking_signal = round(tracking_signal, 6)
    
    # NSE (Nash–Sutcliffe Efficiency):
    # NSE = 1 - [ sum((y_true - y_pred)^2) / sum((y_true - mean(y_true))^2 ) ]
    numerator   = np.sum((y_true_arr - y_pred_arr) ** 2)
    denominator = np.sum((y_true_arr - np.mean(y_true_arr)) ** 2)
    
    # Sau khi ravel, denominator là float; chỉ cần so sánh bình thường
    if denominator == 0:
        nse = np.nan
    else:
        nse = 1 - numerator / denominator
        nse = round(nse, 6)
    
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "Tracking Signal": tracking_signal,
        "NSE": nse
    }

# %% [markdown]
# ### Dự báo và trực quan

# %%
# Trực quan hóa dữ liệu dự báo không dùng index
def plot_forecast(y_true, y_pred, title="Lake level forecast", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_true
    mean_yt = np.mean(y_true)
    std_yt = np.std(y_true, ddof=1)

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_true)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_true)))

    # Tạo trục x là các chỉ mục tuần tự
    x = np.arange(len(y_true))

    # Vẽ biểu đồ
    plt.figure(figsize=(10, 5))

    # Vẽ dữ liệu thực tế
    plt.plot(x, y_true, label="Actual value", color="blue", linestyle='-', alpha=0.7)

    # Vẽ dự báo
    plt.plot(x, y_pred, label="Predicted value", color="red", linestyle='--', alpha=0.7)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(x, ci_lower, ci_upper, color='gray', alpha=0.3, label='99.9% CI')

    # Thiết lập tiêu đề và nhãn
    plt.title(title)
    plt.xlabel("Time Steps")
    plt.ylabel("Water Level (m)")
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.5)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Thực hiện từng phần

# %% [markdown]
# ### Tiền xử lý dữ liệu số

# %%
# Đọc dữ liệu đầu vào
path_data = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\KaNak.csv"
data = read_data_number(path_data, time_col="thoi_gian")

# Tạo DataFrame chứa thời gian và mực nước
y_t = create_dataframe(data, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2")

# %% [markdown]
# ### Chia dữ liệu

# %%
time_steps = 7

scaler_X, scaler_y, X_data, y_data = scaler(y_t, time_steps)
# X_data, y_data = scaler_v1(df_ts, time_steps)

X_train, y_train, X_val, y_val, X_test, y_test = split_data(X_data, y_data, time_steps)
# Out:
# Kích thước X_train: (1017, 7, 2)
# Kích thước X_val: (218, 7, 2)
# Kích thước X_test: (218, 7, 2)
# Kích thước y_train: (1017, 1)
# Kích thước y_val: (218, 1)
# Kích thước y_test: (218, 1)

# %% [markdown]
# ### Huấn luyện ARIMA

# %%
model, history = train_model(X_train, y_train,
                             X_val, y_val,
                             epochs=200,
                             batch_size=16,
                             save_best_model='./BestModel/best_model_goc_LSTM_KN.hdf5')
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 63/64 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 1: val_loss improved from inf to 0.14598, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 2s 9ms/step - loss: 0.0207 - val_loss: 0.1460
# Epoch 2/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0161
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.2017
# Epoch 3/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0094
# Epoch 3: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.2390
# Epoch 4/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0082
# Epoch 4: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.2435
# Epoch 5/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0080
# Epoch 5: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.2431
# Epoch 6/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0063
# Epoch 6: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.2182
# Epoch 7/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0068
# Epoch 7: val_loss did not improve from 0.14598
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.1497
# Epoch 8/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0060
# Epoch 8: val_loss improved from 0.14598 to 0.11611, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.1161
# Epoch 9/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 9: val_loss improved from 0.11611 to 0.06533, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0653
# Epoch 10/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0047
# Epoch 10: val_loss improved from 0.06533 to 0.03508, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0351
# Epoch 11/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0060
# Epoch 11: val_loss improved from 0.03508 to 0.01020, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0102
# Epoch 12/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0054
# Epoch 12: val_loss improved from 0.01020 to 0.00259, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 13/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0070
# Epoch 13: val_loss improved from 0.00259 to 0.00197, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0020
# Epoch 14/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0048
# Epoch 14: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 15/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0057
# Epoch 15: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 16/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0064
# Epoch 16: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0023
# Epoch 17/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0059
# Epoch 17: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 18/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0075
# Epoch 18: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0031
# Epoch 19/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0065
# Epoch 19: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0026
# Epoch 20/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0058
# Epoch 20: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 21/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 21: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 22/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0055
# Epoch 22: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0027
# Epoch 23/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 23: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 24/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0079
# Epoch 24: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0040
# Epoch 25/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 25: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 26/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 26: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 27/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0053
# Epoch 27: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0027
# Epoch 28/200
# 56/64 [=========================>....] - ETA: 0s - loss: 0.0068
# Epoch 28: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0035
# Epoch 29/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 29: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0024
# Epoch 30/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 30: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0030
# Epoch 31/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0068
# Epoch 31: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 32/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0063
# Epoch 32: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0029
# Epoch 33/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 33: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0025
# Epoch 34/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0071
# Epoch 34: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0039
# Epoch 35/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 35: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 36/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 36: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0022
# Epoch 37/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0059
# Epoch 37: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 38/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 38: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0030
# Epoch 39/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 39: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 40/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0056
# Epoch 40: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 41/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0053
# Epoch 41: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0024
# Epoch 42/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0051
# Epoch 42: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 43/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0058
# Epoch 43: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 44/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0056
# Epoch 44: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 45/200
# 43/64 [===================>..........] - ETA: 0s - loss: 0.0056
# Epoch 45: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 46/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0052
# Epoch 46: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 47/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0058
# Epoch 47: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0023
# Epoch 48/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0072
# Epoch 48: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0024
# Epoch 49/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 49: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 50/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 50: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0023
# Epoch 51/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 51: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 52/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0059
# Epoch 52: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 53/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0061
# Epoch 53: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 54/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0046
# Epoch 54: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 55/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 55: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0020
# Epoch 56/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0069
# Epoch 56: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 57/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0060
# Epoch 57: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0023
# Epoch 58/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0058
# Epoch 58: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 59/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0063
# Epoch 59: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 60/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 60: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 61/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0057
# Epoch 61: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0024
# Epoch 62/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0071
# Epoch 62: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0020
# Epoch 63/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 63: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 64/200
# 51/64 [======================>.......] - ETA: 0s - loss: 0.0045
# Epoch 64: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 65/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0059
# Epoch 65: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 66/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 66: val_loss did not improve from 0.00197
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 67/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0062
# Epoch 67: val_loss improved from 0.00197 to 0.00191, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 68/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0055
# Epoch 68: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0024
# Epoch 69/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 69: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 70/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 70: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 71/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 71: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 72/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 72: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 73/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 73: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0027
# Epoch 74/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0058
# Epoch 74: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0023
# Epoch 75/200
# 63/64 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 75: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0024
# Epoch 76/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0069
# Epoch 76: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0032
# Epoch 77/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0059
# Epoch 77: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0031
# Epoch 78/200
# 47/64 [=====================>........] - ETA: 0s - loss: 0.0055
# Epoch 78: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0022
# Epoch 79/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0048
# Epoch 79: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0022
# Epoch 80/200
# 50/64 [======================>.......] - ETA: 0s - loss: 0.0058
# Epoch 80: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 81/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 81: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 82/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 82: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0025
# Epoch 83/200
# 46/64 [====================>.........] - ETA: 0s - loss: 0.0052
# Epoch 83: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 84/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0046
# Epoch 84: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 85/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0074
# Epoch 85: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0020
# Epoch 86/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0047
# Epoch 86: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 87/200
# 42/64 [==================>...........] - ETA: 0s - loss: 0.0056
# Epoch 87: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 88/200
# 64/64 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 88: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0029
# Epoch 89/200
# 44/64 [===================>..........] - ETA: 0s - loss: 0.0046
# Epoch 89: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0031
# Epoch 90/200
# 45/64 [====================>.........] - ETA: 0s - loss: 0.0065
# Epoch 90: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 91/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 91: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 92/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0047
# Epoch 92: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0022
# Epoch 93/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 93: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 94/200
# 51/64 [======================>.......] - ETA: 0s - loss: 0.0050
# Epoch 94: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 95/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 95: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 96/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 96: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 97/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0067
# Epoch 97: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0023
# Epoch 98/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 98: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 99/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 99: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 100/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 100: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 101/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0045
# Epoch 101: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0019
# Epoch 102/200
# 56/64 [=========================>....] - ETA: 0s - loss: 0.0061
# Epoch 102: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 103/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0055
# Epoch 103: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 104/200
# 50/64 [======================>.......] - ETA: 0s - loss: 0.0053
# Epoch 104: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0019
# Epoch 105/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 105: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 106/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 106: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 107/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0064
# Epoch 107: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0036
# Epoch 108/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 108: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 109/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0059
# Epoch 109: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 110/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 110: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 111/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0061
# Epoch 111: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 112/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0056
# Epoch 112: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 113/200
# 53/64 [=======================>......] - ETA: 0s - loss: 0.0053
# Epoch 113: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 114/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0044
# Epoch 114: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 115/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 115: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 116/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 116: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 117/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0070
# Epoch 117: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 118/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 118: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 119/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 119: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 120/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0061
# Epoch 120: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 121/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 121: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0020
# Epoch 122/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 122: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 123/200
# 62/64 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 123: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 124/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0062
# Epoch 124: val_loss did not improve from 0.00191
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 125/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 125: val_loss improved from 0.00191 to 0.00185, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 126/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 126: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 127/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 127: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0038
# Epoch 128/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 128: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 129/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 129: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 130/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 130: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0022
# Epoch 131/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 131: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0025
# Epoch 132/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 132: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0035
# Epoch 133/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 133: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 134/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 134: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 135/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0064
# Epoch 135: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 136/200
# 52/64 [=======================>......] - ETA: 0s - loss: 0.0053
# Epoch 136: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 137/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0062
# Epoch 137: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0019
# Epoch 138/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 138: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 139/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 139: val_loss did not improve from 0.00185
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 140/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0065
# Epoch 140: val_loss improved from 0.00185 to 0.00179, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0018
# Epoch 141/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 141: val_loss improved from 0.00179 to 0.00175, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 142/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 142: val_loss did not improve from 0.00175
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 143/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 143: val_loss did not improve from 0.00175
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 144/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0053
# Epoch 144: val_loss did not improve from 0.00175
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 145/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 145: val_loss did not improve from 0.00175
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 146/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0050
# Epoch 146: val_loss improved from 0.00175 to 0.00164, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 147/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 147: val_loss did not improve from 0.00164
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 148/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 148: val_loss did not improve from 0.00164
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 149/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 149: val_loss did not improve from 0.00164
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 150/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 150: val_loss improved from 0.00164 to 0.00137, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 151/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0050
# Epoch 151: val_loss improved from 0.00137 to 0.00132, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 152/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0052
# Epoch 152: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 153/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 153: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 154/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 154: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0022
# Epoch 155/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0076
# Epoch 155: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 156/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0064
# Epoch 156: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0017
# Epoch 157/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0061
# Epoch 157: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 158/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 158: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 159/200
# 56/64 [=========================>....] - ETA: 0s - loss: 0.0054
# Epoch 159: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 160/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 160: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0015
# Epoch 161/200
# 51/64 [======================>.......] - ETA: 0s - loss: 0.0056
# Epoch 161: val_loss improved from 0.00132 to 0.00132, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 162/200
# 56/64 [=========================>....] - ETA: 0s - loss: 0.0067
# Epoch 162: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0017
# Epoch 163/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0073
# Epoch 163: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 164/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 164: val_loss did not improve from 0.00132
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 165/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0053
# Epoch 165: val_loss improved from 0.00132 to 0.00122, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 166/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.0052
# Epoch 166: val_loss did not improve from 0.00122
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 167/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0064
# Epoch 167: val_loss did not improve from 0.00122
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 168/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0048
# Epoch 168: val_loss did not improve from 0.00122
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 169/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 169: val_loss improved from 0.00122 to 0.00117, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0012
# Epoch 170/200
# 50/64 [======================>.......] - ETA: 0s - loss: 0.0055
# Epoch 170: val_loss improved from 0.00117 to 0.00110, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 171/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 171: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0015
# Epoch 172/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 172: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 173/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 173: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0012
# Epoch 174/200
# 56/64 [=========================>....] - ETA: 0s - loss: 0.0051
# Epoch 174: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 175/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0053
# Epoch 175: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 176/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 176: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 177/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 177: val_loss did not improve from 0.00110
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 178/200
# 47/64 [=====================>........] - ETA: 0s - loss: 0.0062
# Epoch 178: val_loss improved from 0.00110 to 0.00108, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 179/200
# 53/64 [=======================>......] - ETA: 0s - loss: 0.0058
# Epoch 179: val_loss did not improve from 0.00108
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 180/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 180: val_loss did not improve from 0.00108
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 181/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0067
# Epoch 181: val_loss improved from 0.00108 to 0.00084, saving model to ./BestModel\best_model_goc_LSTM_KN.hdf5
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 8.3755e-04
# Epoch 182/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0064
# Epoch 182: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 183/200
# 55/64 [========================>.....] - ETA: 0s - loss: 0.0058
# Epoch 183: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 184/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0044
# Epoch 184: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 185/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0063
# Epoch 185: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 186/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 186: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 187/200
# 53/64 [=======================>......] - ETA: 0s - loss: 0.0044
# Epoch 187: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0010
# Epoch 188/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0041
# Epoch 188: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 189/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 189: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0026
# Epoch 190/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 190: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 191/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 191: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 192/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 192: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 193/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 193: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 194/200
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0054
# Epoch 194: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 195/200
# 54/64 [========================>.....] - ETA: 0s - loss: 0.0063
# Epoch 195: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0010
# Epoch 196/200
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 196: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 197/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 197: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0012
# Epoch 198/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 198: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 8.8920e-04
# Epoch 199/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 199: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 200/200
# 61/64 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 200: val_loss did not improve from 0.00084
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0014

# %% [markdown]
# ### Đánh giá mô hình dự báo trên tập test

# %%
# Đọc model tốt nhất
from keras.models import load_model
model = load_model('./BestModel/best_model_goc_LSTM_KN.hdf5')

# Dự đoán trên tập validation
y_pred = model.predict(X_test)

y_pred, y_test = inverse_transform_data(scaler_y, y_pred, y_test)

evaluate_metrics(y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 2ms/step
# {'MAE': 0.429992,
#  'MSE': 0.324606,
#  'RMSE': 0.569742,
#  'Tracking Signal': -0.147697,
#  'NSE': 0.986439}

# %%
plot_forecast(y_test, y_pred)
# Out:
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)

# Đánh giá
evaluate_metrics(y_true_out, y_t_out)
# Out:
# {'MAE': 0.41098,
#  'MSE': 0.29811,
#  'RMSE': 0.545995,
#  'Tracking Signal': 0.074299,
#  'NSE': 0.986436}
