# %% [markdown]
# # Import thư viện

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
from skimage.feature import hog
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import SimpleRNN, Dense, Dropout, Input, BatchNormalization, GlobalAveragePooling1D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# # Trích xuất đặc trưng từ ảnh

# %%
def extract_hog_from_image(img_path, target_size=(320, 320)):
    # Đọc ảnh dưới dạng grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Không thể đọc ảnh từ đường dẫn: {img_path}")

    # Thay đổi kích thước ảnh
    img = cv2.resize(img, target_size)

    # Tạo mask nhị phân từ ảnh (giá trị ngưỡng 127)
    _, mask = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

    # Trích xuất đặc trưng HOG
    features, _ = hog(mask, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True)
    return features

# %%
def process_image_folder(folder_path, target_size=(320, 320)):
    features_list = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            hog_features = extract_hog_from_image(img_path, target_size)
            features_list.append(hog_features)

    return features_list

# %%
# Đưa vector đặc trưng về giá trị
def reduce_features_to_scalar(features_list):
    features_array = np.array(features_list)

    # Tính L2 norm (độ dài vector)
    f_t = np.linalg.norm(features_array, axis=1)

    return f_t

# %%
def create_feature_dataframe(image_folder, features, col_time='filename', col_feature='f_t'):
    file_names = sorted(os.listdir(image_folder))

    # Chuyển features thành danh sách hai chiều nếu cần
    if isinstance(features, np.ndarray):
        if features.ndim == 1:
            features = features.reshape(-1, 1)  # Chuyển thành mảng 2D nếu là 1D
        features = features.tolist()
    elif isinstance(features, list):
        if all(isinstance(row, (int, float, np.float64, np.int64)) for row in features):
            features = [[row] for row in features]  # Chuyển thành danh sách 2D nếu là danh sách 1D
    else:
        raise TypeError("features phải là list hoặc numpy.ndarray")

    assert len(file_names) == len(features), "Số file ảnh không khớp với số dòng trong features"

    # Tạo DataFrame
    df = pd.DataFrame(features, columns=[col_feature])
    df.insert(0, col_time, file_names)

    return df

# %% [markdown]
# # Đọc và xử lý dữ liệu số

# %%
def read_data_number(data_path, time_col="thoi_gian"):
    # Đọc dữ liệu từ file CSV
    data = pd.read_csv(data_path)

    # Chuyển đổi cột thời gian sang kiểu datetime và đặt làm index
    data[time_col] = pd.to_datetime(data[time_col])
    data.set_index(time_col, inplace=True)

    # Tái lấy mẫu và tính toán thống kê
    y_t = data[['Mực nước hồ (m)', 'Lưu lượng đến hồ (m³/s)']].resample("D").mean()

    return y_t

# %%
def create_dataframe(y_t, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2"):
    df = pd.DataFrame({time_col: y_t.index,
                       value_col_1: y_t['Mực nước hồ (m)'].values,
                       value_col_2: y_t['Lưu lượng đến hồ (m³/s)'].values})
    return df

# %% [markdown]
# # Kết hợp đặc trưng dữ liệu

# %% [markdown]
# ### Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu số gốc

# %%
def rescale_features(df, col="f_t", new_min=0, new_max=1):
    # Tạo một bản sao của DataFrame để không thay đổi dữ liệu gốc
    df_rescaled = df.copy()

    # Lấy dữ liệu của cột cần chuẩn hóa
    col_data = df[col]
    old_min = col_data.min()
    old_max = col_data.max()

    # Kiểm tra tránh chia cho 0 nếu tất cả giá trị giống nhau
    if old_min == old_max:
        df_rescaled[col] = new_min
    else:
        df_rescaled[col] = new_min + (col_data - old_min) * (new_max - new_min) / (old_max - old_min)

    return df_rescaled

# %% [markdown]
# ### Xác định điểm bất thường

# %%
def adjust_y_t(y_t, f_t, alpha):
    mean_y = y_t.mean()
    std_y = y_t.std()

    # Khoảng tin cậy 99,9% dựa trên trung bình và sai số chuẩn
    a = mean_y - alpha * (std_y / np.sqrt(len(y_t)))
    b = mean_y + alpha * (std_y / np.sqrt(len(y_t)))

    # Áp dụng điều chỉnh dựa trên điều kiện
    adjusted_y = np.where(
        (y_t >= a) & (y_t <= b), mean_y, np.where(y_t > b, ((y_t * f_t + mean_y) / (f_t)), ((y_t * f_t) / (1 + f_t)) )
    )

    return pd.Series(adjusted_y, index=y_t.index)

# %% [markdown]
# ### Tính biến ngoại sinh X_t

# %%
def cal_exogenous_variable(y_t, f_t, alpha, time_col="thoi_gian", y_value_col="y_t_1", filename_col="filename", f_t_col="f_t",
                             year_month_col="year_month", f_t_value_col="f_t_value", X_t_col="X_t"):
    # Kiểm tra các cột cần thiết
    required_y_t_cols = {time_col, y_value_col}
    required_f_t_cols = {filename_col, f_t_col}
    if not required_y_t_cols.issubset(y_t.columns):
        raise ValueError(f"DataFrame y_t cần chứa các cột: {required_y_t_cols}")
    if not required_f_t_cols.issubset(f_t.columns):
        raise ValueError(f"DataFrame f_t cần chứa các cột: {required_f_t_cols}")

    # Đảm bảo không thay đổi dữ liệu gốc
    y_t = y_t.copy()
    f_t = f_t.copy()

    # Chuyển đổi cột thời gian sang kiểu datetime và tạo cột year_month
    y_t[time_col] = pd.to_datetime(y_t[time_col])
    y_t[year_month_col] = y_t[time_col].dt.strftime("%Y-%m")

    # Chuẩn hóa tên file trong f_t và tạo cột year_month
    f_t[year_month_col] = (
        f_t[filename_col]
        .str.replace(".jpg", "", regex=True)
        .str.replace("_", "-", regex=False)
    )

    # Tạo từ điển ánh xạ: year_month -> f_t
    mapping = f_t.set_index(year_month_col)[f_t_col].to_dict()

    # Ánh xạ giá trị f_t tương ứng vào y_t; nếu không có giá trị tương ứng, gán mặc định 1.0
    y_t[f_t_value_col] = y_t[year_month_col].map(mapping).fillna(1.0)

    # Điều chỉnh y_t thành X_t sử dụng hàm adjust_y_t (hàm này cần được định nghĩa)
    y_t[X_t_col] = adjust_y_t(y_t[y_value_col], y_t[f_t_value_col], alpha)
    # y_t[X_t_col] = general_transition(y_t[y_value_col], y_t[f_t_value_col], alpha, delta=0.5)

    return y_t[[time_col, X_t_col]]

# %%
def plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_t
    mean_yt = y_t[y_col].mean()
    std_yt = y_t[y_col].std()

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_t)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_t)))

    # Tạo figure với kích thước đã cho
    plt.figure(figsize=(10, 6))

    # Vẽ giá trị X_t dưới dạng scatter
    plt.scatter(X_t[time_col], X_t[x_col], color='blue', label=x_col, s=20)

    # Vẽ giá trị y_t dưới dạng đường line
    plt.plot(X_t[time_col], y_t[y_col], color='red', label=y_col, linewidth=2)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(X_t[time_col], ci_lower, ci_upper,
                     color='gray', alpha=0.3, label='99.9% CI')

    # Cấu hình biểu đồ
    plt.title(f"Biểu đồ của {x_col} và {y_col} theo thời gian với khoảng tin cậy 99.9%")
    plt.xlabel("Thời gian")
    plt.ylabel("Giá trị")
    plt.legend(loc='upper left')
    plt.grid(True)

    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Áp dụng LSTM để dự đoán

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = df[['X_t', 'y_t_1', 'y_t_2']]
    y = df[['y_t_1']]

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler_X, scaler_y, X_data, y_data

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước X_train:", X_train.shape)
    print("Kích thước X_val:", X_val.shape)
    print("Kích thước X_test:", X_test.shape)
    print("Kích thước y_train:", y_train.shape)
    print("Kích thước y_val:", y_val.shape)
    print("Kích thước y_test:", y_test.shape)

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# ### Xây dựng mô hình LSTM

# %%
def build_forecast_model(time_steps, features, lstm_units=[64, 32], dropout_rate=0.3):
    inp = Input(shape=(time_steps, features))

    # Bi-directional Encoder
    x = SimpleRNN(lstm_units[0], return_sequences=True, activation='tanh')(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = SimpleRNN(lstm_units[1], return_sequences=True, activation='tanh')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    # Pooling để gom thông tin cả chuỗi
    x = GlobalAveragePooling1D()(x)

    # Dense layers
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    # Output scalar
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=inp, outputs=out)
    return model

def train_model(X_train, y_train, X_val, y_val,epochs=100, batch_size=32, save_best_model='best_model.h5', initial_lr=1e-3):
    time_steps, features = X_train.shape[1], X_train.shape[2]
    model = build_forecast_model(time_steps, features)

    # Compile với optimizer và loss phù hợp cho hồi quy
    optimizer = Adam(learning_rate=initial_lr)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Callbacks: lưu model tốt nhất, dừng sớm, giảm lr khi plateau
    checkpoint = ModelCheckpoint(save_best_model, monitor='val_loss',save_best_only=True, mode='min', verbose=1)

    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[checkpoint],
                        verbose=2)

    return model, history

# %% [markdown]
# ### Đánh giá mô hình

# %%
# Xác định điểm bất thường
def evaluate_outside_confidence(y_test, y_true, alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_test
    mean_yt = np.mean(y_test)
    std_yt = np.std(y_test, ddof=1)  # ddof=1 để tính std của mẫu

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_test)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_test)))

    # Xác định các index mà y_test nằm ngoài khoảng tin cậy
    outside_ci_indices = np.where((y_test < ci_lower) | (y_test > ci_upper))[0]

    # Truy xuất dữ liệu đúng cách
    y_t_outside = y_test.iloc[outside_ci_indices]
    y_true_outside = y_true.iloc[outside_ci_indices]

    return y_t_outside, y_true_outside

# %%
def evaluate_metrics(y_true, y_pred):
    # Chuyển về numpy array 1D để mọi phép tính sum đều cho ra scalar
    y_true_arr = np.ravel(y_true)
    y_pred_arr = np.ravel(y_pred)

    mae = round(mean_absolute_error(y_true_arr, y_pred_arr), 6)
    mse = round(mean_squared_error(y_true_arr, y_pred_arr), 6)
    rmse = round(np.sqrt(mse), 6)

    # Tính sai số dự báo
    errors = y_true_arr - y_pred_arr

    # Tracking Signal: TS = Tổng sai số dự báo tích lũy / Tổng độ lệch tuyệt đối của sai số
    tracking_signal = np.sum(errors) / np.sum(np.abs(errors))
    tracking_signal = round(tracking_signal, 6)

    # NSE (Nash–Sutcliffe Efficiency):
    # NSE = 1 - [ sum((y_true - y_pred)^2) / sum((y_true - mean(y_true))^2 ) ]
    numerator   = np.sum((y_true_arr - y_pred_arr) ** 2)
    denominator = np.sum((y_true_arr - np.mean(y_true_arr)) ** 2)

    # Sau khi ravel, denominator là float; chỉ cần so sánh bình thường
    if denominator == 0:
        nse = np.nan
    else:
        nse = 1 - numerator / denominator
        nse = round(nse, 6)

    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "Tracking Signal": tracking_signal,
        "NSE": nse
    }

# %% [markdown]
# ### Dự báo và trực quan

# %%
# Trực quan hóa dữ liệu dự báo không dùng index
def plot_forecast(y_true, y_pred, title="Lake level forecast", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_true
    mean_yt = np.mean(y_true)
    std_yt = np.std(y_true, ddof=1)

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_true)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_true)))

    # Tạo trục x là các chỉ mục tuần tự
    x = np.arange(len(y_true))

    # Vẽ biểu đồ
    plt.figure(figsize=(10, 5))

    # Vẽ dữ liệu thực tế
    plt.plot(x, y_true, label="Actual value", color="blue", linestyle='-', alpha=0.7)

    # Vẽ dự báo
    plt.plot(x, y_pred, label="Predicted value", color="red", linestyle='--', alpha=0.7)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(x, ci_lower, ci_upper, color='gray', alpha=0.3, label='99.9% CI')

    # Thiết lập tiêu đề và nhãn
    plt.title(title)
    plt.xlabel("Time Steps")
    plt.ylabel("Water Level (m)")
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.5)

    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Thực hiện từng phần

# %% [markdown]
# ### Tiền xử lý dữ liệu ảnh

# %%
# Đọc dữ liệu ảnh và trích xuất HOG
folder_img = r"/content/drive/MyDrive/CoChau/EAI-2024/DataSetAnKhe/images_AnKhe"
features = process_image_folder(folder_img)

# Đưa vector đặc trưng về giá trị
f_t_features = reduce_features_to_scalar(features)
f_t = create_feature_dataframe(folder_img, f_t_features, col_time='filename', col_feature='f_t')

# %% [markdown]
# ### Tiền xử lý dữ liệu số

# %%
# Đọc dữ liệu đầu vào
path_data = r"/content/drive/MyDrive/CoChau/EAI-2024/DataSetAnKhe/data_so_AnKhe/AnKhe.csv"
data = read_data_number(path_data, time_col="thoi_gian")

# Tạo DataFrame chứa thời gian và mực nước
y_t = create_dataframe(data, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2")

# %% [markdown]
# ### Chuẩn hóa khoảng và kết hợp đặc trưng

# %%
# Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu mực nước gốc
f_t = rescale_features(f_t, col="f_t", new_min=y_t['y_t_1'].min(), new_max=y_t['y_t_1'].max())

# %%
# Tính X_t
alpha = 3.291 # 99.9%
X_t = cal_exogenous_variable(y_t, f_t, alpha)

# Trực quan X_t
plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=alpha)

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuyển 'thoi_gian' về datetime để đảm bảo kiểu dữ liệu đúng
X_t["thoi_gian"] = pd.to_datetime(X_t["thoi_gian"])
y_t["thoi_gian"] = pd.to_datetime(y_t["thoi_gian"])

# Gộp hai DataFrame theo 'thoi_gian'
df_ts = pd.merge(y_t[["thoi_gian", "y_t_1", "y_t_2"]], X_t[["thoi_gian", "X_t"]], on="thoi_gian", how="inner")
df_ts.set_index("thoi_gian", inplace=True)

# %%
time_steps = 7

scaler_X, scaler_y, X_data, y_data = scaler(df_ts, time_steps)
# X_data, y_data = scaler_v1(df_ts, time_steps)

X_train, y_train, X_val, y_val, X_test, y_test = split_data(X_data, y_data, time_steps)
# Out:
# Kích thước X_train: (1273, 7, 3)
# Kích thước X_val: (273, 7, 3)
# Kích thước X_test: (273, 7, 3)
# Kích thước y_train: (1273, 1)
# Kích thước y_val: (273, 1)
# Kích thước y_test: (273, 1)

# %% [markdown]
# ### Huấn luyện ARIMA

# %%
model, history = train_model(X_train, y_train,
                             X_val, y_val,
                             epochs=200,
                             batch_size=16,
                             save_best_model='/content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras',
                             initial_lr=1e-3)
# Out:
# Epoch 1/200
#
# Epoch 1: val_loss improved from inf to 0.07067, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 11s - 138ms/step - loss: 0.0709 - val_loss: 0.0707
# Epoch 2/200
#
# Epoch 2: val_loss improved from 0.07067 to 0.01642, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0446 - val_loss: 0.0164
# Epoch 3/200
#
# Epoch 3: val_loss improved from 0.01642 to 0.01027, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0304 - val_loss: 0.0103
# Epoch 4/200
#
# Epoch 4: val_loss improved from 0.01027 to 0.01011, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0244 - val_loss: 0.0101
# Epoch 5/200
#
# Epoch 5: val_loss improved from 0.01011 to 0.00971, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0209 - val_loss: 0.0097
# Epoch 6/200
#
# Epoch 6: val_loss did not improve from 0.00971
# 80/80 - 0s - 5ms/step - loss: 0.0163 - val_loss: 0.0098
# Epoch 7/200
#
# Epoch 7: val_loss improved from 0.00971 to 0.00861, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0154 - val_loss: 0.0086
# Epoch 8/200
#
# Epoch 8: val_loss did not improve from 0.00861
# 80/80 - 0s - 5ms/step - loss: 0.0144 - val_loss: 0.0086
# Epoch 9/200
#
# Epoch 9: val_loss improved from 0.00861 to 0.00757, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0126 - val_loss: 0.0076
# Epoch 10/200
#
# Epoch 10: val_loss improved from 0.00757 to 0.00709, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0124 - val_loss: 0.0071
# Epoch 11/200
#
# Epoch 11: val_loss did not improve from 0.00709
# 80/80 - 0s - 5ms/step - loss: 0.0116 - val_loss: 0.0076
# Epoch 12/200
#
# Epoch 12: val_loss did not improve from 0.00709
# 80/80 - 0s - 5ms/step - loss: 0.0114 - val_loss: 0.0073
# Epoch 13/200
#
# Epoch 13: val_loss did not improve from 0.00709
# 80/80 - 0s - 5ms/step - loss: 0.0105 - val_loss: 0.0085
# Epoch 14/200
#
# Epoch 14: val_loss improved from 0.00709 to 0.00598, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 15/200
#
# Epoch 15: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 16/200
#
# Epoch 16: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0091 - val_loss: 0.0076
# Epoch 17/200
#
# Epoch 17: val_loss did not improve from 0.00598
# 80/80 - 0s - 4ms/step - loss: 0.0088 - val_loss: 0.0064
# Epoch 18/200
#
# Epoch 18: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0097 - val_loss: 0.0068
# Epoch 19/200
#
# Epoch 19: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0084 - val_loss: 0.0066
# Epoch 20/200
#
# Epoch 20: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0087 - val_loss: 0.0066
# Epoch 21/200
#
# Epoch 21: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0089 - val_loss: 0.0060
# Epoch 22/200
#
# Epoch 22: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 23/200
#
# Epoch 23: val_loss did not improve from 0.00598
# 80/80 - 0s - 4ms/step - loss: 0.0082 - val_loss: 0.0061
# Epoch 24/200
#
# Epoch 24: val_loss did not improve from 0.00598
# 80/80 - 0s - 5ms/step - loss: 0.0088 - val_loss: 0.0062
# Epoch 25/200
#
# Epoch 25: val_loss did not improve from 0.00598
# 80/80 - 0s - 4ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 26/200
#
# Epoch 26: val_loss improved from 0.00598 to 0.00579, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 27/200
#
# Epoch 27: val_loss improved from 0.00579 to 0.00529, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0078 - val_loss: 0.0053
# Epoch 28/200
#
# Epoch 28: val_loss did not improve from 0.00529
# 80/80 - 0s - 5ms/step - loss: 0.0078 - val_loss: 0.0085
# Epoch 29/200
#
# Epoch 29: val_loss did not improve from 0.00529
# 80/80 - 0s - 5ms/step - loss: 0.0081 - val_loss: 0.0088
# Epoch 30/200
#
# Epoch 30: val_loss did not improve from 0.00529
# 80/80 - 0s - 5ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 31/200
#
# Epoch 31: val_loss did not improve from 0.00529
# 80/80 - 0s - 5ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 32/200
#
# Epoch 32: val_loss improved from 0.00529 to 0.00511, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0074 - val_loss: 0.0051
# Epoch 33/200
#
# Epoch 33: val_loss did not improve from 0.00511
# 80/80 - 0s - 5ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 34/200
#
# Epoch 34: val_loss did not improve from 0.00511
# 80/80 - 0s - 5ms/step - loss: 0.0072 - val_loss: 0.0053
# Epoch 35/200
#
# Epoch 35: val_loss did not improve from 0.00511
# 80/80 - 0s - 5ms/step - loss: 0.0066 - val_loss: 0.0133
# Epoch 36/200
#
# Epoch 36: val_loss did not improve from 0.00511
# 80/80 - 0s - 4ms/step - loss: 0.0070 - val_loss: 0.0082
# Epoch 37/200
#
# Epoch 37: val_loss did not improve from 0.00511
# 80/80 - 0s - 5ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 38/200
#
# Epoch 38: val_loss did not improve from 0.00511
# 80/80 - 0s - 5ms/step - loss: 0.0073 - val_loss: 0.0058
# Epoch 39/200
#
# Epoch 39: val_loss improved from 0.00511 to 0.00498, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 40/200
#
# Epoch 40: val_loss did not improve from 0.00498
# 80/80 - 0s - 5ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 41/200
#
# Epoch 41: val_loss did not improve from 0.00498
# 80/80 - 0s - 4ms/step - loss: 0.0068 - val_loss: 0.0050
# Epoch 42/200
#
# Epoch 42: val_loss did not improve from 0.00498
# 80/80 - 0s - 4ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 43/200
#
# Epoch 43: val_loss improved from 0.00498 to 0.00466, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0070 - val_loss: 0.0047
# Epoch 44/200
#
# Epoch 44: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 45/200
#
# Epoch 45: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 46/200
#
# Epoch 46: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0064 - val_loss: 0.0048
# Epoch 47/200
#
# Epoch 47: val_loss did not improve from 0.00466
# 80/80 - 0s - 4ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 48/200
#
# Epoch 48: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 49/200
#
# Epoch 49: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 50/200
#
# Epoch 50: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0068 - val_loss: 0.0051
# Epoch 51/200
#
# Epoch 51: val_loss did not improve from 0.00466
# 80/80 - 0s - 5ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 52/200
#
# Epoch 52: val_loss improved from 0.00466 to 0.00459, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0066 - val_loss: 0.0046
# Epoch 53/200
#
# Epoch 53: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0064 - val_loss: 0.0051
# Epoch 54/200
#
# Epoch 54: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 55/200
#
# Epoch 55: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 56/200
#
# Epoch 56: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 57/200
#
# Epoch 57: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0061 - val_loss: 0.0068
# Epoch 58/200
#
# Epoch 58: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 59/200
#
# Epoch 59: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 60/200
#
# Epoch 60: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 61/200
#
# Epoch 61: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 62/200
#
# Epoch 62: val_loss did not improve from 0.00459
# 80/80 - 0s - 5ms/step - loss: 0.0061 - val_loss: 0.0112
# Epoch 63/200
#
# Epoch 63: val_loss improved from 0.00459 to 0.00447, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 64/200
#
# Epoch 64: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 65/200
#
# Epoch 65: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 66/200
#
# Epoch 66: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 67/200
#
# Epoch 67: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 68/200
#
# Epoch 68: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 69/200
#
# Epoch 69: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 70/200
#
# Epoch 70: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 71/200
#
# Epoch 71: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0062 - val_loss: 0.0085
# Epoch 72/200
#
# Epoch 72: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 73/200
#
# Epoch 73: val_loss did not improve from 0.00447
# 80/80 - 0s - 4ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 74/200
#
# Epoch 74: val_loss did not improve from 0.00447
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0102
# Epoch 75/200
#
# Epoch 75: val_loss improved from 0.00447 to 0.00435, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 76/200
#
# Epoch 76: val_loss improved from 0.00435 to 0.00433, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0058 - val_loss: 0.0043
# Epoch 77/200
#
# Epoch 77: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0063
# Epoch 78/200
#
# Epoch 78: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 79/200
#
# Epoch 79: val_loss did not improve from 0.00433
# 80/80 - 0s - 4ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 80/200
#
# Epoch 80: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 81/200
#
# Epoch 81: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 82/200
#
# Epoch 82: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 83/200
#
# Epoch 83: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 84/200
#
# Epoch 84: val_loss did not improve from 0.00433
# 80/80 - 0s - 4ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 85/200
#
# Epoch 85: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 86/200
#
# Epoch 86: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 87/200
#
# Epoch 87: val_loss did not improve from 0.00433
# 80/80 - 0s - 5ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 88/200
#
# Epoch 88: val_loss improved from 0.00433 to 0.00428, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 89/200
#
# Epoch 89: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 90/200
#
# Epoch 90: val_loss did not improve from 0.00428
# 80/80 - 0s - 4ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 91/200
#
# Epoch 91: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0073
# Epoch 92/200
#
# Epoch 92: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0066
# Epoch 93/200
#
# Epoch 93: val_loss did not improve from 0.00428
# 80/80 - 0s - 4ms/step - loss: 0.0053 - val_loss: 0.0106
# Epoch 94/200
#
# Epoch 94: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 95/200
#
# Epoch 95: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 96/200
#
# Epoch 96: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0062
# Epoch 97/200
#
# Epoch 97: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 98/200
#
# Epoch 98: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 99/200
#
# Epoch 99: val_loss did not improve from 0.00428
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 100/200
#
# Epoch 100: val_loss improved from 0.00428 to 0.00425, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 6ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 101/200
#
# Epoch 101: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 102/200
#
# Epoch 102: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 103/200
#
# Epoch 103: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0047 - val_loss: 0.0059
# Epoch 104/200
#
# Epoch 104: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 105/200
#
# Epoch 105: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 106/200
#
# Epoch 106: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0074
# Epoch 107/200
#
# Epoch 107: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0091
# Epoch 108/200
#
# Epoch 108: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0070
# Epoch 109/200
#
# Epoch 109: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0058 - val_loss: 0.0043
# Epoch 110/200
#
# Epoch 110: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 111/200
#
# Epoch 111: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 112/200
#
# Epoch 112: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 113/200
#
# Epoch 113: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 114/200
#
# Epoch 114: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 115/200
#
# Epoch 115: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 116/200
#
# Epoch 116: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0114
# Epoch 117/200
#
# Epoch 117: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 118/200
#
# Epoch 118: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0076
# Epoch 119/200
#
# Epoch 119: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 120/200
#
# Epoch 120: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0076
# Epoch 121/200
#
# Epoch 121: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 122/200
#
# Epoch 122: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 123/200
#
# Epoch 123: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 124/200
#
# Epoch 124: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 125/200
#
# Epoch 125: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 126/200
#
# Epoch 126: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 127/200
#
# Epoch 127: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 128/200
#
# Epoch 128: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 129/200
#
# Epoch 129: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 130/200
#
# Epoch 130: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0051 - val_loss: 0.0096
# Epoch 131/200
#
# Epoch 131: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 132/200
#
# Epoch 132: val_loss did not improve from 0.00425
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 133/200
#
# Epoch 133: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0053 - val_loss: 0.0095
# Epoch 134/200
#
# Epoch 134: val_loss did not improve from 0.00425
# 80/80 - 0s - 4ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 135/200
#
# Epoch 135: val_loss improved from 0.00425 to 0.00423, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 136/200
#
# Epoch 136: val_loss did not improve from 0.00423
# 80/80 - 0s - 5ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 137/200
#
# Epoch 137: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 138/200
#
# Epoch 138: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 139/200
#
# Epoch 139: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 140/200
#
# Epoch 140: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 141/200
#
# Epoch 141: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 142/200
#
# Epoch 142: val_loss did not improve from 0.00423
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 143/200
#
# Epoch 143: val_loss did not improve from 0.00423
# 80/80 - 0s - 4ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 144/200
#
# Epoch 144: val_loss improved from 0.00423 to 0.00403, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 145/200
#
# Epoch 145: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0069
# Epoch 146/200
#
# Epoch 146: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0051 - val_loss: 0.0070
# Epoch 147/200
#
# Epoch 147: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 148/200
#
# Epoch 148: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 149/200
#
# Epoch 149: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 150/200
#
# Epoch 150: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 151/200
#
# Epoch 151: val_loss did not improve from 0.00403
# 80/80 - 0s - 4ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 152/200
#
# Epoch 152: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 153/200
#
# Epoch 153: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 154/200
#
# Epoch 154: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0084
# Epoch 155/200
#
# Epoch 155: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0095
# Epoch 156/200
#
# Epoch 156: val_loss did not improve from 0.00403
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 157/200
#
# Epoch 157: val_loss improved from 0.00403 to 0.00385, saving model to /content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras
# 80/80 - 0s - 5ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 158/200
#
# Epoch 158: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 159/200
#
# Epoch 159: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 160/200
#
# Epoch 160: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0071
# Epoch 161/200
#
# Epoch 161: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 162/200
#
# Epoch 162: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 163/200
#
# Epoch 163: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 164/200
#
# Epoch 164: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 165/200
#
# Epoch 165: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 166/200
#
# Epoch 166: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 167/200
#
# Epoch 167: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 168/200
#
# Epoch 168: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 169/200
#
# Epoch 169: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0044 - val_loss: 0.0120
# Epoch 170/200
#
# Epoch 170: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0051 - val_loss: 0.0059
# Epoch 171/200
#
# Epoch 171: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 172/200
#
# Epoch 172: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 173/200
#
# Epoch 173: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 174/200
#
# Epoch 174: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 175/200
#
# Epoch 175: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 176/200
#
# Epoch 176: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 177/200
#
# Epoch 177: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 178/200
#
# Epoch 178: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 179/200
#
# Epoch 179: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 180/200
#
# Epoch 180: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 181/200
#
# Epoch 181: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 182/200
#
# Epoch 182: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 183/200
#
# Epoch 183: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 184/200
#
# Epoch 184: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 185/200
#
# Epoch 185: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 186/200
#
# Epoch 186: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 187/200
#
# Epoch 187: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 188/200
#
# Epoch 188: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 189/200
#
# Epoch 189: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 190/200
#
# Epoch 190: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 191/200
#
# Epoch 191: val_loss did not improve from 0.00385
# 80/80 - 0s - 4ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 192/200
#
# Epoch 192: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 193/200
#
# Epoch 193: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0042 - val_loss: 0.0069
# Epoch 194/200
#
# Epoch 194: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 195/200
#
# Epoch 195: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 196/200
#
# Epoch 196: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0098
# Epoch 197/200
#
# Epoch 197: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0044 - val_loss: 0.0121
# Epoch 198/200
#
# Epoch 198: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 199/200
#
# Epoch 199: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 200/200
#
# Epoch 200: val_loss did not improve from 0.00385
# 80/80 - 0s - 5ms/step - loss: 0.0044 - val_loss: 0.0086

# %% [markdown]
# ### Đánh giá mô hình dự báo trên tập test

# %%
# Đọc model tốt nhất
from keras.models import load_model
model = load_model('/content/drive/MyDrive/CoChau/EAI-2024/Results/best_model_Fusion_HOG_RNN.keras')

# Dự đoán trên tập validation
y_pred = model.predict(X_test)

y_pred, y_test = inverse_transform_data(scaler_y, y_pred, y_test)

evaluate_metrics(y_test, y_pred)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# {'MAE': 0.208466,
#  'MSE': 0.084545,
#  'RMSE': np.float64(0.290766),
#  'Tracking Signal': np.float64(0.30431),
#  'NSE': np.float64(0.343917)}

# %%
plot_forecast(y_test, y_pred)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:3800: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)

# Đánh giá
evaluate_metrics(y_true_out, y_t_out)
# Out:
# {'MAE': 0.215141,
#  'MSE': 0.089559,
#  'RMSE': np.float64(0.299264),
#  'Tracking Signal': np.float64(-0.300562),
#  'NSE': np.float64(0.035907)}
