# %% [markdown]
# # Import thư viện

# %%
import cv2
from skimage.feature import hog
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import LSTM, Dense, Dropout, Input, BatchNormalization, GlobalAveragePooling1D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# Đọc model tốt nhất
from keras.models import load_model
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Trích xuất đặc trưng từ ảnh

# %%
def extract_hog_from_image(img_path, target_size=(320, 320)):
    # Đọc ảnh dưới dạng grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Không thể đọc ảnh từ đường dẫn: {img_path}")
        
    # Thay đổi kích thước ảnh
    img = cv2.resize(img, target_size)
    
    # Tạo mask nhị phân từ ảnh (giá trị ngưỡng 127)
    _, mask = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    
    # Trích xuất đặc trưng HOG
    features, _ = hog(mask, orientations=9, pixels_per_cell=(8, 8), 
                      cells_per_block=(2, 2), visualize=True)
    return features

# %%
def process_image_folder(folder_path, target_size=(320, 320)):
    features_list = []
    
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            hog_features = extract_hog_from_image(img_path, target_size)
            features_list.append(hog_features)
    
    return features_list

# %%
# Đưa vector đặc trưng về giá trị 
def reduce_features_to_scalar(features_list):
    features_array = np.array(features_list)

    # Tính L2 norm (độ dài vector)
    f_t = np.linalg.norm(features_array, axis=1)
    
    return f_t

# %%
def create_feature_dataframe(image_folder, features, col_time='filename', col_feature='f_t'):
    file_names = sorted(os.listdir(image_folder))
    
    # Chuyển features thành danh sách hai chiều nếu cần
    if isinstance(features, np.ndarray):
        if features.ndim == 1:
            features = features.reshape(-1, 1)  # Chuyển thành mảng 2D nếu là 1D
        features = features.tolist()
    elif isinstance(features, list):
        if all(isinstance(row, (int, float, np.float64, np.int64)) for row in features):
            features = [[row] for row in features]  # Chuyển thành danh sách 2D nếu là danh sách 1D
    else:
        raise TypeError("features phải là list hoặc numpy.ndarray")
    
    assert len(file_names) == len(features), "Số file ảnh không khớp với số dòng trong features"
    
    # Tạo DataFrame
    df = pd.DataFrame(features, columns=[col_feature])
    df.insert(0, col_time, file_names)
    
    return df

# %% [markdown]
# # Đọc và xử lý dữ liệu số

# %%
def read_data_number(data_path, time_col="thoi_gian"):
    # Đọc dữ liệu từ file CSV
    data = pd.read_csv(data_path)
    
    # Chuyển đổi cột thời gian sang kiểu datetime và đặt làm index
    data[time_col] = pd.to_datetime(data[time_col])
    data.set_index(time_col, inplace=True)
    
    # Tái lấy mẫu và tính toán thống kê
    y_t = data[['Mực nước hồ (m)', 'Lưu lượng đến hồ (m³/s)']].resample("D").mean()
    
    return y_t

# %%
def create_dataframe(y_t, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2"):
    df = pd.DataFrame({time_col: y_t.index, 
                       value_col_1: y_t['Mực nước hồ (m)'].values, 
                       value_col_2: y_t['Lưu lượng đến hồ (m³/s)'].values})
    return df

# %% [markdown]
# # Kết hợp đặc trưng dữ liệu

# %% [markdown]
# ### Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu số gốc

# %%
def rescale_features(df, col="f_t", new_min=0, new_max=1):
    # Tạo một bản sao của DataFrame để không thay đổi dữ liệu gốc
    df_rescaled = df.copy()
    
    # Lấy dữ liệu của cột cần chuẩn hóa
    col_data = df[col]
    old_min = col_data.min()
    old_max = col_data.max()

    # Kiểm tra tránh chia cho 0 nếu tất cả giá trị giống nhau
    if old_min == old_max:
        df_rescaled[col] = new_min
    else:
        df_rescaled[col] = new_min + (col_data - old_min) * (new_max - new_min) / (old_max - old_min)

    return df_rescaled

# %% [markdown]
# ### Xác định điểm bất thường

# %%
def adjust_y_t(y_t, f_t, alpha):
    mean_y = y_t.mean()
    std_y = y_t.std()

    # Khoảng tin cậy 99,9% dựa trên trung bình và sai số chuẩn
    a = mean_y - alpha * (std_y / np.sqrt(len(y_t)))
    b = mean_y + alpha * (std_y / np.sqrt(len(y_t)))

    # Áp dụng điều chỉnh dựa trên điều kiện
    adjusted_y = np.where(
        (y_t >= a) & (y_t <= b), mean_y, np.where(y_t > b, ((y_t * f_t + mean_y) / (f_t)), ((y_t * f_t) / (1 + f_t)) )
    )

    return pd.Series(adjusted_y, index=y_t.index)

# %% [markdown]
# ### Tính biến ngoại sinh X_t

# %%
def cal_exogenous_variable(y_t, f_t, alpha, time_col="thoi_gian", y_value_col="y_t_1", filename_col="filename", f_t_col="f_t",
                             year_month_col="year_month", f_t_value_col="f_t_value", X_t_col="X_t"):
    # Kiểm tra các cột cần thiết
    required_y_t_cols = {time_col, y_value_col}
    required_f_t_cols = {filename_col, f_t_col}
    if not required_y_t_cols.issubset(y_t.columns):
        raise ValueError(f"DataFrame y_t cần chứa các cột: {required_y_t_cols}")
    if not required_f_t_cols.issubset(f_t.columns):
        raise ValueError(f"DataFrame f_t cần chứa các cột: {required_f_t_cols}")
    
    # Đảm bảo không thay đổi dữ liệu gốc
    y_t = y_t.copy()
    f_t = f_t.copy()
    
    # Chuyển đổi cột thời gian sang kiểu datetime và tạo cột year_month
    y_t[time_col] = pd.to_datetime(y_t[time_col])
    y_t[year_month_col] = y_t[time_col].dt.strftime("%Y-%m")
    
    # Chuẩn hóa tên file trong f_t và tạo cột year_month
    f_t[year_month_col] = (
        f_t[filename_col]
        .str.replace(".jpg", "", regex=True)
        .str.replace("_", "-", regex=False)
    )
    
    # Tạo từ điển ánh xạ: year_month -> f_t
    mapping = f_t.set_index(year_month_col)[f_t_col].to_dict()
    
    # Ánh xạ giá trị f_t tương ứng vào y_t; nếu không có giá trị tương ứng, gán mặc định 1.0
    y_t[f_t_value_col] = y_t[year_month_col].map(mapping).fillna(1.0)
    
    # Điều chỉnh y_t thành X_t sử dụng hàm adjust_y_t (hàm này cần được định nghĩa)
    y_t[X_t_col] = adjust_y_t(y_t[y_value_col], y_t[f_t_value_col], alpha)
    # y_t[X_t_col] = general_transition(y_t[y_value_col], y_t[f_t_value_col], alpha, delta=0.5)
    
    return y_t[[time_col, X_t_col]]

# %%
def plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_t
    mean_yt = y_t[y_col].mean()
    std_yt = y_t[y_col].std()

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_t)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_t)))

    # Tạo figure với kích thước đã cho
    plt.figure(figsize=(10, 6))
    
    # Vẽ giá trị X_t dưới dạng scatter
    plt.scatter(X_t[time_col], X_t[x_col], color='blue', label=x_col, s=20)
    
    # Vẽ giá trị y_t dưới dạng đường line
    plt.plot(X_t[time_col], y_t[y_col], color='red', label=y_col, linewidth=2)
    
    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(X_t[time_col], ci_lower, ci_upper,
                     color='gray', alpha=0.3, label='99.9% CI')
    
    # Cấu hình biểu đồ
    plt.title(f"Biểu đồ của {x_col} và {y_col} theo thời gian với khoảng tin cậy 99.9%")
    plt.xlabel("Thời gian")
    plt.ylabel("Giá trị")
    plt.legend(loc='upper left')
    plt.grid(True)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Áp dụng LSTM để dự đoán

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
def create_dataset(X: pd.DataFrame, y: pd.DataFrame, n_steps: int):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X.iloc[i : i + n_steps].values)        # lấy n_steps dòng liên tiếp
        ys.append(y.iloc[i + n_steps].values)            # lấy giá trị ở dòng i+n_steps
    return np.array(Xs), np.array(ys).reshape(-1, 1)      # reshape cho y thành (samples, 1)

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuẩn hóa dữ liệu
def split_train_test(X_data, y_data):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.85)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_test, y_test = X_data[train_length:], y_data[train_length:]

    print("Kích thước X_train:", X_train.shape)
    print("Kích thước X_test:", X_test.shape)
    print("Kích thước y_train:", y_train.shape)
    print("Kích thước y_test:", y_test.shape)

    return X_train, y_train, X_test, y_test

# %%
import numpy as np
from sklearn.model_selection import KFold

def split_data(X_data, y_data, n_splits=5, random_state=42):
    # 1) Large folds trên dữ liệu gốc
    kf_large = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    large_folds = [test_idx for _, test_idx in kf_large.split(X_data)]

    # 2) Với mỗi large fold, chia thành small folds
    small_folds = []  # small_folds[i] = list length n_splits, mỗi phần là chỉ số gốc
    for large_idx in large_folds:
        X_large = X_data[large_idx]
        kf_small = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
        small_idx_list = []
        for _, small_idx in kf_small.split(X_large):
            # small_idx là chỉ số relative trong X_large, chuyển về chỉ số gốc
            small_idx_list.append(large_idx[small_idx])
        small_folds.append(small_idx_list)

    # 3) Tạo các split train/val
    splits = []
    for k in range(n_splits):
        # val: small fold k của mỗi large fold
        val_idx = np.concatenate([small_folds[i][k] for i in range(n_splits)], axis=0)
        # train: tất cả small fold j != k
        train_idx = np.concatenate(
            [small_folds[i][j]
             for i in range(n_splits)
             for j in range(n_splits) if j != k],
            axis=0
        )

        X_train, y_train = X_data[train_idx], y_data[train_idx]
        X_val,   y_val   = X_data[val_idx],   y_data[val_idx]
        splits.append((X_train, y_train, X_val, y_val))

    return splits

# %% [markdown]
# ### Xây dựng mô hình LSTM

# %%
def build_forecast_model(time_steps, features, lstm_units=[64, 32], dropout_rate=0.3):
    inp = Input(shape=(time_steps, features))
    
    # Bi-directional Encoder
    x = LSTM(lstm_units[0], return_sequences=True, activation='tanh')(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    x = LSTM(lstm_units[1], return_sequences=True, activation='tanh')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    # Pooling để gom thông tin cả chuỗi
    x = GlobalAveragePooling1D()(x)
    
    # Dense layers
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    # Output scalar
    out = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inp, outputs=out)
    return model

# %%
def train_model(X_train, y_train, X_val, y_val, epochs=100, batch_size=32, save_best_model='best_model.h5', initial_lr=1e-3):
    tf.keras.backend.clear_session()

    time_steps, features = X_train.shape[1], X_train.shape[2]
    model = build_forecast_model(time_steps, features)

    # Compile với optimizer và loss phù hợp cho hồi quy
    optimizer = Adam(learning_rate=initial_lr)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Callbacks: lưu model tốt nhất, dừng sớm, giảm lr khi plateau
    checkpoint = ModelCheckpoint(save_best_model, monitor='val_loss',save_best_only=True, mode='min', verbose=1)
    
    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[checkpoint],
                        verbose=2)

    # Nạp lại weights tốt nhất trước khi return
    model.load_weights(save_best_model)
    return model, history

# %% [markdown]
# ### Đánh giá mô hình

# %%
# Xác định điểm bất thường
def evaluate_outside_confidence(y_test, y_true, alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_test
    mean_yt = np.mean(y_test)
    std_yt = np.std(y_test, ddof=1)  # ddof=1 để tính std của mẫu

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_test)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_test)))

    # Xác định các index mà y_test nằm ngoài khoảng tin cậy
    outside_ci_indices = np.where((y_test < ci_lower) | (y_test > ci_upper))[0]

    # Truy xuất dữ liệu đúng cách
    y_t_outside = y_test[outside_ci_indices]
    y_true_outside = y_true[outside_ci_indices]

    return y_t_outside, y_true_outside

# %%
def evaluate_metrics(y_true, y_pred):
    # Chuyển về numpy array 1D để mọi phép tính sum đều cho ra scalar
    y_true_arr = np.ravel(y_true)
    y_pred_arr = np.ravel(y_pred)

    mae = round(mean_absolute_error(y_true_arr, y_pred_arr), 6)
    mse = round(mean_squared_error(y_true_arr, y_pred_arr), 6)
    rmse = round(np.sqrt(mse), 6)
    
    # Tính sai số dự báo
    errors = y_true_arr - y_pred_arr
    
    # Tracking Signal: TS = Tổng sai số dự báo tích lũy / Tổng độ lệch tuyệt đối của sai số
    tracking_signal = np.sum(errors) / np.sum(np.abs(errors))
    tracking_signal = round(tracking_signal, 6)
    
    # NSE (Nash–Sutcliffe Efficiency):
    # NSE = 1 - [ sum((y_true - y_pred)^2) / sum((y_true - mean(y_true))^2 ) ]
    numerator   = np.sum((y_true_arr - y_pred_arr) ** 2)
    denominator = np.sum((y_true_arr - np.mean(y_true_arr)) ** 2)
    
    # Sau khi ravel, denominator là float; chỉ cần so sánh bình thường
    if denominator == 0:
        nse = np.nan
    else:
        nse = 1 - numerator / denominator
        nse = round(nse, 6)
    
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "Tracking Signal": tracking_signal,
        "NSE": nse
    }

# %% [markdown]
# ### Dự báo và trực quan

# %%
# Trực quan hóa dữ liệu dự báo không dùng index
def plot_forecast(y_true, y_pred, title="Lake level forecast", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_true
    mean_yt = np.mean(y_true)
    std_yt = np.std(y_true, ddof=1)

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_true)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_true)))

    # Tạo trục x là các chỉ mục tuần tự
    x = np.arange(len(y_true))

    # Vẽ biểu đồ
    plt.figure(figsize=(10, 5))

    # Vẽ dữ liệu thực tế
    plt.plot(x, y_true, label="Actual value", color="blue", linestyle='-', alpha=0.7)

    # Vẽ dự báo
    plt.plot(x, y_pred, label="Predicted value", color="red", linestyle='--', alpha=0.7)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(x, ci_lower, ci_upper, color='gray', alpha=0.3, label='99.9% CI')

    # Thiết lập tiêu đề và nhãn
    plt.title(title)
    plt.xlabel("Time Steps")
    plt.ylabel("Water Level (m)")
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.5)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Thực hiện từng phần

# %% [markdown]
# ### Tiền xử lý dữ liệu ảnh

# %%
# Đọc dữ liệu ảnh và trích xuất HOG
folder_img = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\masks"
features = process_image_folder(folder_img)

# Đưa vector đặc trưng về giá trị
f_t_features = reduce_features_to_scalar(features)
f_t = create_feature_dataframe(folder_img, f_t_features, col_time='filename', col_feature='f_t')

# %% [markdown]
# ### Tiền xử lý dữ liệu số

# %%
# Đọc dữ liệu đầu vào
path_data = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\KaNak.csv"
data = read_data_number(path_data, time_col="thoi_gian")

# Tạo DataFrame chứa thời gian và mực nước
y_t = create_dataframe(data, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2")
y_t.head()
# Out:
#    thoi_gian       y_t_1      y_t_2
# 0 2019-01-01  490.139583  28.558333
# 1 2019-01-02  490.497500  21.766667
# 2 2019-01-03  490.781667  13.733333
# 3 2019-01-04  490.941667  11.275000
# 4 2019-01-05  491.097917  11.250000

# %% [markdown]
# ### Chuẩn hóa khoảng và kết hợp đặc trưng

# %%
# Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu mực nước gốc
f_t = rescale_features(f_t, col="f_t", new_min=y_t['y_t_1'].min(), new_max=y_t['y_t_1'].max())

# %%
# Tính X_t
alpha = 3.291 # 99.9%
X_t = cal_exogenous_variable(y_t, f_t, alpha)

# Trực quan X_t
# plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=alpha)

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuyển 'thoi_gian' về datetime để đảm bảo kiểu dữ liệu đúng
X_t["thoi_gian"] = pd.to_datetime(X_t["thoi_gian"])
y_t["thoi_gian"] = pd.to_datetime(y_t["thoi_gian"])

# Gộp hai DataFrame theo 'thoi_gian'
df_ts = pd.merge(y_t[["thoi_gian", "y_t_1", "y_t_2"]], X_t[["thoi_gian", "X_t"]], on="thoi_gian", how="inner")
df_ts.set_index("thoi_gian", inplace=True)

# %%
# Chuẩn hóa dữ liệu
def scaler_data(X, y):
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    return scaler_X, scaler_y, X, y

# %%
time_steps = 7

# Tạo chuỗi dữ liệu
X_data, y_data = create_dataset(df_ts[['X_t', 'y_t_1', 'y_t_2']], df_ts[['y_t_1']], time_steps)

# Chia dữ liệu
X_train_val, y_train_val, X_test, y_test = split_train_test(X_data, y_data)
# Out:
# Kích thước X_train: (1235, 7, 3)
# Kích thước X_test: (219, 7, 3)
# Kích thước y_train: (1235, 1)
# Kích thước y_test: (219, 1)

# %%
# Chia K-Fold
splits = split_data(X_train_val, y_train_val)

# %% [markdown]
# ### Huấn luyện ARIMA

# %%
    # 2) Fit scaler & transform X_train_fold, X_val_fold, y_train_fold, y_val_fold
    # scaler_X, scaler_y, X_tr, y_tr, X_vl, y_vl = prepare_scaler_and_transform(splits[i][0], splits[i][1], splits[i][2], splits[i][3])

# %%
rest_time = 30
for i in range(5):
    print(f"—— Fold {i+1} ——")

    # 1) Clear session để release graph cũ
    tf.keras.backend.clear_session()

    # 2) Fit scaler chỉ trên X_train và y_train của fold
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_tr = splits[i][0]
    y_tr = splits[i][1]
    X_vl = splits[i][2]
    y_vl = splits[i][3]

    # reshape nếu cần: X có shape (n_samples, time_steps, n_feat) -> flatten để scaler
    n_samples_tr, ts, n_feat = X_tr.shape
    X_tr_flat = X_tr.reshape(-1, n_feat)
    X_vl_flat = X_vl.reshape(-1, n_feat)

    X_tr_s = scaler_X.fit_transform(X_tr_flat).reshape(n_samples_tr, ts, n_feat)
    X_vl_s = scaler_X.transform(X_vl_flat).reshape(X_vl.shape)

    y_tr_s = scaler_y.fit_transform(y_tr.reshape(-1, 1))
    y_vl_s = scaler_y.transform(y_vl.reshape(-1, 1))

    # 3) Train và lưu model tốt nhất của fold
    model, history = train_model(
        X_tr_s, y_tr_s,
        X_vl_s, y_vl_s,
        epochs=100,
        batch_size=16,
        save_best_model=f'./BestModel/KFold_HOG_LSTM_Fusion_{i+1}_KN.hdf5',
        initial_lr=1e-3
    )

    # 4) Tải lại weights tốt nhất
    model = load_model(f'./BestModel/KFold_HOG_LSTM_Fusion_{i+1}_KN.hdf5')

    # 5) Transform X_test (giữ nguyên y_test gốc)
    X_test = X_test  # shape (n_samples_test, ts, n_feat)
    n_samples_test = X_test.shape[0]
    X_test_flat = X_test.reshape(-1, n_feat)
    X_test_s = scaler_X.transform(X_test_flat).reshape(n_samples_test, ts, n_feat)

    # 6) Dự đoán trên tập X_test đã scale
    y_pred_s = model.predict(X_test_s)

    # 7) Inverse scale để về giá trị gốc
    y_pred = scaler_y.inverse_transform(y_pred_s).reshape(-1, 1)

    # 8) Đánh giá metric trên giá trị gốc
    print()
    print(f"Kết quả Fold {i+1}")
    print(evaluate_metrics(y_test, y_pred))

    # 10) Lấy điểm bất thường và đánh giá tiếp
    y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)
    print(evaluate_metrics(y_true_out, y_t_out))

    # 9) Vẽ đồ thị forecast
    plot_forecast(y_test, y_pred)

    print(f"Kết thúc Fold {i+1}. Nghỉ {rest_time}s...\n")
# Out:
# —— Fold 1 ——
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#
# Epoch 1: val_loss improved from inf to 0.12067, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 4s - loss: 0.0500 - val_loss: 0.1207 - 4s/epoch - 62ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.12067 to 0.10983, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0293 - val_loss: 0.1098 - 422ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.10983 to 0.09174, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0917 - 365ms/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.09174 to 0.06959, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0195 - val_loss: 0.0696 - 379ms/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.06959 to 0.04722, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0185 - val_loss: 0.0472 - 371ms/epoch - 6ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.04722 to 0.02898, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0180 - val_loss: 0.0290 - 370ms/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.02898 to 0.01087, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0151 - val_loss: 0.0109 - 374ms/epoch - 6ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.01087 to 0.00625, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0153 - val_loss: 0.0062 - 372ms/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00625 to 0.00296, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0142 - val_loss: 0.0030 - 360ms/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.00296
# 62/62 - 0s - loss: 0.0146 - val_loss: 0.0034 - 321ms/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00296
# 62/62 - 0s - loss: 0.0117 - val_loss: 0.0033 - 327ms/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00296
# 62/62 - 0s - loss: 0.0118 - val_loss: 0.0042 - 318ms/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00296
# 62/62 - 0s - loss: 0.0125 - val_loss: 0.0039 - 320ms/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.00296 to 0.00202, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0106 - val_loss: 0.0020 - 384ms/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0137 - val_loss: 0.0028 - 325ms/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0112 - val_loss: 0.0038 - 328ms/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0044 - 347ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0100 - val_loss: 0.0030 - 325ms/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0107 - val_loss: 0.0035 - 326ms/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0041 - 316ms/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0106 - val_loss: 0.0028 - 331ms/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0047 - 326ms/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0088 - val_loss: 0.0033 - 343ms/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00202
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0035 - 344ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.00202 to 0.00177, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0018 - 368ms/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0025 - 336ms/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0029 - 326ms/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0092 - val_loss: 0.0036 - 340ms/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0018 - 338ms/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0100 - val_loss: 0.0023 - 321ms/epoch - 5ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0092 - val_loss: 0.0033 - 321ms/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0077 - val_loss: 0.0023 - 318ms/epoch - 5ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0027 - 320ms/epoch - 5ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0025 - 318ms/epoch - 5ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0019 - 317ms/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0018 - 325ms/epoch - 5ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00177
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0019 - 312ms/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.00177 to 0.00153, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0015 - 400ms/epoch - 6ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0098 - val_loss: 0.0032 - 325ms/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0020 - 318ms/epoch - 5ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0032 - 324ms/epoch - 5ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0022 - 352ms/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0022 - 344ms/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0024 - 345ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0018 - 310ms/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0033 - 362ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0028 - 333ms/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0017 - 325ms/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0021 - 350ms/epoch - 6ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0015 - 437ms/epoch - 7ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0017 - 364ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0036 - 381ms/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0028 - 365ms/epoch - 6ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0021 - 383ms/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0019 - 367ms/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0016 - 382ms/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00153
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0023 - 366ms/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: val_loss improved from 0.00153 to 0.00139, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0014 - 473ms/epoch - 8ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0022 - 498ms/epoch - 8ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0024 - 388ms/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0021 - 380ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0015 - 366ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0017 - 412ms/epoch - 7ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0033 - 407ms/epoch - 7ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0018 - 397ms/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0020 - 381ms/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0017 - 384ms/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0014 - 378ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0017 - 367ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0017 - 368ms/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0015 - 399ms/epoch - 6ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0017 - 449ms/epoch - 7ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0021 - 380ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0016 - 355ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0017 - 360ms/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0015 - 364ms/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0029 - 359ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0042 - val_loss: 0.0017 - 360ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00139
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0022 - 394ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss improved from 0.00139 to 0.00136, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0014 - 421ms/epoch - 7ms/step
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.00136 to 0.00135, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0014 - 406ms/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0021 - 356ms/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0026 - 370ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0014 - 352ms/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0016 - 349ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0014 - 355ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0017 - 355ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0015 - 364ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0018 - 351ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0023 - 358ms/epoch - 6ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0022 - 352ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0037 - 378ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0021 - 360ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0025 - 363ms/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0020 - 349ms/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0025 - 350ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0016 - 364ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0016 - 353ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0019 - 358ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss improved from 0.00135 to 0.00133, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0013 - 407ms/epoch - 7ms/step
# 7/7 [==============================] - 1s 3ms/step
#
# Kết quả Fold 1
# {'MAE': 0.570788, 'MSE': 0.486075, 'RMSE': 0.697191, 'Tracking Signal': -0.570241, 'NSE': 0.979617}
# {'MAE': 0.570848, 'MSE': 0.491425, 'RMSE': 0.701017, 'Tracking Signal': 0.604417, 'NSE': 0.976936}
# Kết thúc Fold 1. Nghỉ 30s...
#
# —— Fold 2 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.10632, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 4s - loss: 0.0402 - val_loss: 0.1063 - 4s/epoch - 62ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.10632 to 0.10516, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0217 - val_loss: 0.1052 - 435ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.10516 to 0.10497, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0185 - val_loss: 0.1050 - 467ms/epoch - 8ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.10497 to 0.09867, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0182 - val_loss: 0.0987 - 420ms/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.09867 to 0.08817, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0160 - val_loss: 0.0882 - 402ms/epoch - 6ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.08817 to 0.05971, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0138 - val_loss: 0.0597 - 407ms/epoch - 7ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.05971 to 0.03134, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0146 - val_loss: 0.0313 - 421ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.03134 to 0.01738, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0123 - val_loss: 0.0174 - 442ms/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.01738 to 0.00547, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0120 - val_loss: 0.0055 - 478ms/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00547 to 0.00175, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0133 - val_loss: 0.0017 - 439ms/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.00175 to 0.00152, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0015 - 459ms/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0107 - val_loss: 0.0021 - 419ms/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0099 - val_loss: 0.0030 - 412ms/epoch - 7ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0099 - val_loss: 0.0016 - 448ms/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0025 - 426ms/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0024 - 419ms/epoch - 7ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0092 - val_loss: 0.0021 - 418ms/epoch - 7ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0020 - 415ms/epoch - 7ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0093 - val_loss: 0.0029 - 409ms/epoch - 7ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0029 - 416ms/epoch - 7ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0095 - val_loss: 0.0017 - 416ms/epoch - 7ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0018 - 435ms/epoch - 7ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0022 - 420ms/epoch - 7ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00152
# 62/62 - 0s - loss: 0.0099 - val_loss: 0.0017 - 403ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.00152 to 0.00141, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0014 - 470ms/epoch - 8ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0037 - 444ms/epoch - 7ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0014 - 410ms/epoch - 7ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0018 - 423ms/epoch - 7ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0023 - 414ms/epoch - 7ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0036 - 418ms/epoch - 7ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00141
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0022 - 420ms/epoch - 7ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.00141 to 0.00128, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0013 - 448ms/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00128
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0023 - 418ms/epoch - 7ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00128
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0019 - 425ms/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00128
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0027 - 420ms/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.00128 to 0.00124, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0012 - 464ms/epoch - 7ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00124
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0021 - 415ms/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00124
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0017 - 449ms/epoch - 7ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00124
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0014 - 418ms/epoch - 7ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00124
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0014 - 444ms/epoch - 7ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.00124 to 0.00097, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0073 - val_loss: 9.7468e-04 - 456ms/epoch - 7ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0016 - 423ms/epoch - 7ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0018 - 421ms/epoch - 7ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0082 - val_loss: 0.0024 - 417ms/epoch - 7ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0014 - 443ms/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0012 - 415ms/epoch - 7ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0021 - 450ms/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0021 - 425ms/epoch - 7ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0022 - 450ms/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0015 - 417ms/epoch - 7ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0038 - 417ms/epoch - 7ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0029 - 425ms/epoch - 7ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0016 - 417ms/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0014 - 417ms/epoch - 7ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0077 - val_loss: 0.0011 - 424ms/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0018 - 424ms/epoch - 7ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0012 - 428ms/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00097
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0013 - 428ms/epoch - 7ms/step
# Epoch 59/100
#
# Epoch 59: val_loss improved from 0.00097 to 0.00089, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0078 - val_loss: 8.8940e-04 - 472ms/epoch - 8ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0063 - val_loss: 8.9858e-04 - 423ms/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0030 - 441ms/epoch - 7ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0013 - 424ms/epoch - 7ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0018 - 459ms/epoch - 7ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0023 - 461ms/epoch - 7ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0060 - val_loss: 9.9341e-04 - 428ms/epoch - 7ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0019 - 421ms/epoch - 7ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0010 - 423ms/epoch - 7ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0012 - 448ms/epoch - 7ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00089
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0013 - 425ms/epoch - 7ms/step
# Epoch 70/100
#
# Epoch 70: val_loss improved from 0.00089 to 0.00076, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0062 - val_loss: 7.6278e-04 - 469ms/epoch - 8ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00076
# 62/62 - 0s - loss: 0.0059 - val_loss: 8.3250e-04 - 424ms/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00076
# 62/62 - 0s - loss: 0.0054 - val_loss: 8.0846e-04 - 406ms/epoch - 7ms/step
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.00076 to 0.00070, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 1s - loss: 0.0056 - val_loss: 7.0269e-04 - 504ms/epoch - 8ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0055 - val_loss: 9.2787e-04 - 404ms/epoch - 7ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0056 - val_loss: 7.9687e-04 - 418ms/epoch - 7ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0048 - val_loss: 9.4996e-04 - 420ms/epoch - 7ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.00070 to 0.00050, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0070 - val_loss: 4.9982e-04 - 480ms/epoch - 8ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0064 - val_loss: 6.2793e-04 - 420ms/epoch - 7ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0024 - 430ms/epoch - 7ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0017 - 423ms/epoch - 7ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0014 - 415ms/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0010 - 381ms/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0063 - val_loss: 9.0822e-04 - 389ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0011 - 424ms/epoch - 7ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0014 - 386ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0050 - val_loss: 7.1683e-04 - 378ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0057 - val_loss: 8.4806e-04 - 382ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0055 - val_loss: 8.8415e-04 - 388ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0044 - val_loss: 8.6926e-04 - 387ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0069 - val_loss: 6.3463e-04 - 405ms/epoch - 7ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00050
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0012 - 384ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss improved from 0.00050 to 0.00045, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0064 - val_loss: 4.5344e-04 - 474ms/epoch - 8ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0064 - val_loss: 8.5617e-04 - 449ms/epoch - 7ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0051 - val_loss: 9.0351e-04 - 427ms/epoch - 7ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0046 - val_loss: 5.2714e-04 - 425ms/epoch - 7ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0042 - val_loss: 5.2102e-04 - 428ms/epoch - 7ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0011 - 432ms/epoch - 7ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0057 - val_loss: 9.1089e-04 - 448ms/epoch - 7ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0020 - 428ms/epoch - 7ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00045
# 62/62 - 0s - loss: 0.0047 - val_loss: 7.4990e-04 - 424ms/epoch - 7ms/step
# 7/7 [==============================] - 1s 3ms/step
#
# Kết quả Fold 2
# {'MAE': 0.420355, 'MSE': 0.26448, 'RMSE': 0.514276, 'Tracking Signal': 0.188996, 'NSE': 0.988909}
# {'MAE': 0.414931, 'MSE': 0.26103, 'RMSE': 0.510911, 'Tracking Signal': -0.18728, 'NSE': 0.988019}
# Kết thúc Fold 2. Nghỉ 30s...
#
# —— Fold 3 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.10815, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 5s - loss: 0.0431 - val_loss: 0.1081 - 5s/epoch - 78ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 0.10815
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.1221 - 438ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.10815
# 62/62 - 0s - loss: 0.0208 - val_loss: 0.1142 - 430ms/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.10815 to 0.08210, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0184 - val_loss: 0.0821 - 490ms/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.08210 to 0.06364, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 1s - loss: 0.0167 - val_loss: 0.0636 - 553ms/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.06364 to 0.04424, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0154 - val_loss: 0.0442 - 479ms/epoch - 8ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.04424 to 0.01755, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0140 - val_loss: 0.0176 - 485ms/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.01755 to 0.00566, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0125 - val_loss: 0.0057 - 470ms/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00566 to 0.00421, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0142 - val_loss: 0.0042 - 470ms/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00421 to 0.00379, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0128 - val_loss: 0.0038 - 470ms/epoch - 8ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0116 - val_loss: 0.0049 - 424ms/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0105 - val_loss: 0.0063 - 426ms/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0103 - val_loss: 0.0044 - 429ms/epoch - 7ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0046 - 423ms/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0044 - 434ms/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0107 - val_loss: 0.0054 - 437ms/epoch - 7ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0046 - 453ms/epoch - 7ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0043 - 428ms/epoch - 7ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0042 - 428ms/epoch - 7ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0077 - val_loss: 0.0042 - 426ms/epoch - 7ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0044 - 424ms/epoch - 7ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0038 - 434ms/epoch - 7ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0052 - 430ms/epoch - 7ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0082 - val_loss: 0.0044 - 430ms/epoch - 7ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0045 - 426ms/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0056 - 423ms/epoch - 7ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0040 - 430ms/epoch - 7ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0047 - 430ms/epoch - 7ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00379
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0041 - 420ms/epoch - 7ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.00379 to 0.00345, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 1s - loss: 0.0071 - val_loss: 0.0035 - 512ms/epoch - 8ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0035 - 426ms/epoch - 7ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0044 - 428ms/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0038 - 438ms/epoch - 7ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0046 - 427ms/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0043 - 429ms/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0082 - val_loss: 0.0037 - 420ms/epoch - 7ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0077 - val_loss: 0.0047 - 440ms/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00345
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0036 - 430ms/epoch - 7ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 0.00345 to 0.00334, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0033 - 476ms/epoch - 8ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00334
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0037 - 433ms/epoch - 7ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.00334 to 0.00314, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0031 - 498ms/epoch - 8ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0039 - 432ms/epoch - 7ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0041 - 430ms/epoch - 7ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0046 - 430ms/epoch - 7ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0047 - 404ms/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0040 - 401ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00314
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0034 - 406ms/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 0.00314 to 0.00307, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0031 - 434ms/epoch - 7ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0036 - 384ms/epoch - 6ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0033 - 396ms/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0034 - 380ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0033 - 433ms/epoch - 7ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0038 - 410ms/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0039 - 414ms/epoch - 7ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0037 - 434ms/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0031 - 430ms/epoch - 7ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0037 - 410ms/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0033 - 440ms/epoch - 7ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0036 - 484ms/epoch - 8ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0048 - 460ms/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0053 - 432ms/epoch - 7ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00307
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0031 - 454ms/epoch - 7ms/step
# Epoch 63/100
#
# Epoch 63: val_loss improved from 0.00307 to 0.00295, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0030 - 477ms/epoch - 8ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00295
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0034 - 424ms/epoch - 7ms/step
# Epoch 65/100
#
# Epoch 65: val_loss improved from 0.00295 to 0.00291, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0029 - 474ms/epoch - 8ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0031 - 430ms/epoch - 7ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0032 - 447ms/epoch - 7ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0030 - 442ms/epoch - 7ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0030 - 426ms/epoch - 7ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0038 - 438ms/epoch - 7ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00291
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0037 - 432ms/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.00291 to 0.00287, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0029 - 474ms/epoch - 8ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0060 - 430ms/epoch - 7ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0031 - 484ms/epoch - 8ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0031 - 428ms/epoch - 7ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0034 - 440ms/epoch - 7ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0029 - 432ms/epoch - 7ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0031 - 429ms/epoch - 7ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0029 - 439ms/epoch - 7ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0033 - 432ms/epoch - 7ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00287
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0032 - 436ms/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_loss improved from 0.00287 to 0.00278, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 1s - loss: 0.0049 - val_loss: 0.0028 - 502ms/epoch - 8ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00278
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0028 - 426ms/epoch - 7ms/step
# Epoch 84/100
#
# Epoch 84: val_loss improved from 0.00278 to 0.00277, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0040 - val_loss: 0.0028 - 470ms/epoch - 8ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0031 - 430ms/epoch - 7ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0033 - 470ms/epoch - 8ms/step
# Epoch 87/100
#
# Epoch 87: val_loss improved from 0.00277 to 0.00249, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0041 - val_loss: 0.0025 - 474ms/epoch - 8ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0026 - 450ms/epoch - 7ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0027 - 438ms/epoch - 7ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0041 - val_loss: 0.0028 - 437ms/epoch - 7ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0028 - 430ms/epoch - 7ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0045 - 443ms/epoch - 7ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0028 - 425ms/epoch - 7ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0032 - 432ms/epoch - 7ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0026 - 434ms/epoch - 7ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0041 - val_loss: 0.0025 - 427ms/epoch - 7ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0041 - val_loss: 0.0041 - 437ms/epoch - 7ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0042 - val_loss: 0.0033 - 459ms/epoch - 7ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0027 - 426ms/epoch - 7ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00249
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0027 - 427ms/epoch - 7ms/step
# 7/7 [==============================] - 1s 2ms/step
#
# Kết quả Fold 3
# {'MAE': 0.591179, 'MSE': 0.487462, 'RMSE': 0.698185, 'Tracking Signal': 0.159232, 'NSE': 0.979559}
# {'MAE': 0.571634, 'MSE': 0.446686, 'RMSE': 0.668346, 'Tracking Signal': -0.097518, 'NSE': 0.9827}
# Kết thúc Fold 3. Nghỉ 30s...
#
# —— Fold 4 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.10030, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 5s - loss: 0.0451 - val_loss: 0.1003 - 5s/epoch - 88ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.10030 to 0.09642, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0249 - val_loss: 0.0964 - 564ms/epoch - 9ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.09642 to 0.07604, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0270 - val_loss: 0.0760 - 560ms/epoch - 9ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.07604 to 0.06822, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0235 - val_loss: 0.0682 - 550ms/epoch - 9ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.06822 to 0.05030, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0188 - val_loss: 0.0503 - 578ms/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.05030 to 0.02064, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0166 - val_loss: 0.0206 - 560ms/epoch - 9ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.02064 to 0.00619, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0168 - val_loss: 0.0062 - 520ms/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.00619 to 0.00447, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0148 - val_loss: 0.0045 - 501ms/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00447 to 0.00242, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 1s - loss: 0.0166 - val_loss: 0.0024 - 512ms/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.00242
# 62/62 - 0s - loss: 0.0147 - val_loss: 0.0034 - 442ms/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.00242 to 0.00209, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0141 - val_loss: 0.0021 - 487ms/epoch - 8ms/step
# Epoch 12/100
#
# ...
#
# Epoch 97: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0012 - 488ms/epoch - 8ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00063
# 62/62 - 1s - loss: 0.0054 - val_loss: 8.8044e-04 - 514ms/epoch - 8ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0013 - 494ms/epoch - 8ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0011 - 494ms/epoch - 8ms/step
# 7/7 [==============================] - 1s 3ms/step
#
# Kết quả Fold 4
# {'MAE': 0.509758, 'MSE': 0.396292, 'RMSE': 0.629517, 'Tracking Signal': -0.238063, 'NSE': 0.983382}
# {'MAE': 0.510861, 'MSE': 0.401831, 'RMSE': 0.633901, 'Tracking Signal': 0.253682, 'NSE': 0.980453}
# Kết thúc Fold 4. Nghỉ 30s...
#
# —— Fold 5 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.10464, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 5s - loss: 0.0342 - val_loss: 0.1046 - 5s/epoch - 86ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.10464 to 0.09575, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0197 - val_loss: 0.0958 - 540ms/epoch - 9ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.09575 to 0.08333, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0158 - val_loss: 0.0833 - 590ms/epoch - 10ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.08333 to 0.07005, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0164 - val_loss: 0.0701 - 532ms/epoch - 9ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.07005 to 0.05045, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0141 - val_loss: 0.0504 - 534ms/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.05045 to 0.03138, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0125 - val_loss: 0.0314 - 531ms/epoch - 9ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.03138 to 0.02336, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0129 - val_loss: 0.0234 - 552ms/epoch - 9ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.02336 to 0.00782, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0113 - val_loss: 0.0078 - 535ms/epoch - 9ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00782 to 0.00290, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0104 - val_loss: 0.0029 - 544ms/epoch - 9ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00290 to 0.00157, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0107 - val_loss: 0.0016 - 524ms/epoch - 8ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.00157 to 0.00147, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0099 - val_loss: 0.0015 - 564ms/epoch - 9ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00147
# 62/62 - 1s - loss: 0.0122 - val_loss: 0.0015 - 514ms/epoch - 8ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00147
# 62/62 - 0s - loss: 0.0109 - val_loss: 0.0031 - 475ms/epoch - 8ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00147
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0025 - 480ms/epoch - 8ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00147
# 62/62 - 1s - loss: 0.0077 - val_loss: 0.0021 - 522ms/epoch - 8ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00147
# 62/62 - 1s - loss: 0.0100 - val_loss: 0.0025 - 501ms/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00147
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0018 - 479ms/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00147
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0022 - 480ms/epoch - 8ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00147
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0021 - 481ms/epoch - 8ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.00147 to 0.00140, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0087 - val_loss: 0.0014 - 531ms/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00140
# 62/62 - 0s - loss: 0.0093 - val_loss: 0.0020 - 481ms/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00140
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0028 - 469ms/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00140
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0027 - 484ms/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00140
# 62/62 - 1s - loss: 0.0086 - val_loss: 0.0018 - 511ms/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.00140 to 0.00140, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0067 - val_loss: 0.0014 - 535ms/epoch - 9ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00140
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0018 - 471ms/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00140
# 62/62 - 1s - loss: 0.0075 - val_loss: 0.0019 - 508ms/epoch - 8ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.00140 to 0.00127, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0064 - val_loss: 0.0013 - 580ms/epoch - 9ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00127
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0020 - 474ms/epoch - 8ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00127
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0015 - 479ms/epoch - 8ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00127
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0020 - 480ms/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00127
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0017 - 484ms/epoch - 8ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00127
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0013 - 480ms/epoch - 8ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.00127 to 0.00115, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0062 - val_loss: 0.0011 - 524ms/epoch - 8ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00115
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0017 - 490ms/epoch - 8ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.00115 to 0.00101, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0065 - val_loss: 0.0010 - 557ms/epoch - 9ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0017 - 470ms/epoch - 8ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0015 - 474ms/epoch - 8ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0013 - 475ms/epoch - 8ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0011 - 477ms/epoch - 8ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0012 - 476ms/epoch - 8ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0012 - 472ms/epoch - 8ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0015 - 479ms/epoch - 8ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0083 - val_loss: 0.0019 - 479ms/epoch - 8ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0011 - 477ms/epoch - 8ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0017 - 473ms/epoch - 8ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0016 - 481ms/epoch - 8ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00101
# 62/62 - 1s - loss: 0.0059 - val_loss: 0.0011 - 505ms/epoch - 8ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0017 - 476ms/epoch - 8ms/step
# Epoch 50/100
#
# Epoch 50: val_loss improved from 0.00101 to 0.00088, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 1s - loss: 0.0048 - val_loss: 8.8248e-04 - 540ms/epoch - 9ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00088
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0012 - 450ms/epoch - 7ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00088
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0010 - 461ms/epoch - 7ms/step
# Epoch 53/100
#
# Epoch 53: val_loss improved from 0.00088 to 0.00081, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0054 - val_loss: 8.0891e-04 - 489ms/epoch - 8ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0023 - 428ms/epoch - 7ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0057 - val_loss: 9.8757e-04 - 444ms/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0012 - 444ms/epoch - 7ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0023 - 438ms/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0020 - 470ms/epoch - 8ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0012 - 434ms/epoch - 7ms/step
# Epoch 60/100
#
# Epoch 60: val_loss improved from 0.00081 to 0.00081, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0051 - val_loss: 8.0708e-04 - 422ms/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0012 - 378ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0056 - val_loss: 9.6719e-04 - 372ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0011 - 374ms/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0011 - 372ms/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0013 - 377ms/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0047 - val_loss: 9.7640e-04 - 372ms/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0016 - 374ms/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0013 - 371ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0083 - val_loss: 0.0039 - 372ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0014 - 370ms/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0011 - 370ms/epoch - 6ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0011 - 378ms/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0053 - val_loss: 8.1021e-04 - 366ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0026 - 372ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0011 - 368ms/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0011 - 371ms/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0011 - 370ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0011 - 366ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0011 - 396ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0013 - 388ms/epoch - 6ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0013 - 416ms/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0016 - 403ms/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0014 - 373ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0063 - val_loss: 8.8789e-04 - 374ms/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00081
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0011 - 371ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss improved from 0.00081 to 0.00071, saving model to ./BestModel\KFold_HOG_LSTM_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0049 - val_loss: 7.1303e-04 - 407ms/epoch - 7ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0053 - val_loss: 8.0142e-04 - 370ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0015 - 370ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0010 - 371ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0011 - 376ms/epoch - 6ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0012 - 371ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0014 - 380ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0046 - val_loss: 8.6355e-04 - 376ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0043 - val_loss: 0.0013 - 372ms/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0086 - 374ms/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0018 - 373ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0054 - val_loss: 9.7111e-04 - 373ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0010 - 395ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0011 - 372ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0044 - val_loss: 8.6865e-04 - 370ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 2ms/step
#
# Kết quả Fold 5
# {'MAE': 0.606601, 'MSE': 0.558529, 'RMSE': 0.747348, 'Tracking Signal': -0.736927, 'NSE': 0.976578}
# {'MAE': 0.610678, 'MSE': 0.566405, 'RMSE': 0.752599, 'Tracking Signal': 0.788349, 'NSE': 0.976938}
# Kết thúc Fold 5. Nghỉ 30s...

# %%
rest_time = 30
for i in range(5):
    print(f"—— Fold {i+1} ——")

    # 1) Clear session để release graph cũ
    tf.keras.backend.clear_session()

    # 2) Chuẩn bị scaler trên X_train, y_train của fold
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_tr, y_tr, _, _ = splits[i]

    # Lấy shape để reshape
    n_samples_tr, ts, n_feat = X_tr.shape

    # Fit scaler_X trên X_tr
    X_tr_flat = X_tr.reshape(-1, n_feat)
    scaler_X.fit(X_tr_flat)

    # Fit scaler_y trên y_tr
    y_tr_flat = y_tr.reshape(-1, 1)
    scaler_y.fit(y_tr_flat)

    # 3) Load model đã train sẵn
    model = load_model(f'./BestModel/KFold_HOG_LSTM_Fusion_{i+1}_KN.hdf5')

    # 4) Chuẩn hoá X_test
    n_samples_test = X_test.shape[0]
    X_test_flat    = X_test.reshape(-1, n_feat)
    X_test_s       = scaler_X.transform(X_test_flat).reshape(n_samples_test, ts, n_feat)

    # 5) Dự đoán và về giá trị gốc
    y_pred_s = model.predict(X_test_s)
    y_pred   = scaler_y.inverse_transform(y_pred_s).reshape(-1, 1)
    y_true   = y_test.reshape(-1, 1)

    # 6) Tính statistics cho y_true và y_pred
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()

    mean_true = np.mean(y_true_flat)
    mean_pred = np.mean(y_pred_flat)
    std_true  = np.std(y_true_flat)
    std_pred  = np.std(y_pred_flat)
    var_true  = np.var(y_true_flat)
    var_pred  = np.var(y_pred_flat)

    print("\n— Statistics (y_true vs y_pred) —")
    print(f"{'':>12} {'y_true':>12} {'y_pred':>12}")
    print(f"{'mean':>12} {mean_true:12.6f} {mean_pred:12.6f}")
    print(f"{'std':>12}  {std_true:12.6f}  {std_pred:12.6f}")
    print(f"{'var':>12}  {var_true:12.6f}  {var_pred:12.6f}\n")
# Out:
# —— Fold 1 ——
# 7/7 [==============================] - 0s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.798706
#          std      4.883319      4.537511
#          var     23.846801     20.589005
#
# —— Fold 2 ——
# 7/7 [==============================] - 0s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.393768
#          std      4.883319      4.586730
#          var     23.846801     21.038090
#
# —— Fold 3 ——
# 7/7 [==============================] - 0s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.379059
#          std      4.883319      4.997396
#          var     23.846801     24.973972
#
# —— Fold 4 ——
# 7/7 [==============================] - 0s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.594543
#          std      4.883319      4.455369
#          var     23.846801     19.850313
#
# —— Fold 5 ——
# 7/7 [==============================] - 0s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.920227
#          std      4.883319      4.871747
#          var     23.846801     23.733917
