# %% [markdown]
# # Import thư viện

# %%
import cv2
from skimage.feature import hog
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import GRU, Dense, Dropout, Input, BatchNormalization, GlobalAveragePooling1D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# Đọc model tốt nhất
from keras.models import load_model
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Trích xuất đặc trưng từ ảnh

# %%
def extract_hog_from_image(img_path, target_size=(320, 320)):
    # Đọc ảnh dưới dạng grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Không thể đọc ảnh từ đường dẫn: {img_path}")
        
    # Thay đổi kích thước ảnh
    img = cv2.resize(img, target_size)
    
    # Tạo mask nhị phân từ ảnh (giá trị ngưỡng 127)
    _, mask = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    
    # Trích xuất đặc trưng HOG
    features, _ = hog(mask, orientations=9, pixels_per_cell=(8, 8), 
                      cells_per_block=(2, 2), visualize=True)
    return features

# %%
def process_image_folder(folder_path, target_size=(320, 320)):
    features_list = []
    
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            hog_features = extract_hog_from_image(img_path, target_size)
            features_list.append(hog_features)
    
    return features_list

# %%
# Đưa vector đặc trưng về giá trị 
def reduce_features_to_scalar(features_list):
    features_array = np.array(features_list)

    # Tính L2 norm (độ dài vector)
    f_t = np.linalg.norm(features_array, axis=1)
    
    return f_t

# %%
def create_feature_dataframe(image_folder, features, col_time='filename', col_feature='f_t'):
    file_names = sorted(os.listdir(image_folder))
    
    # Chuyển features thành danh sách hai chiều nếu cần
    if isinstance(features, np.ndarray):
        if features.ndim == 1:
            features = features.reshape(-1, 1)  # Chuyển thành mảng 2D nếu là 1D
        features = features.tolist()
    elif isinstance(features, list):
        if all(isinstance(row, (int, float, np.float64, np.int64)) for row in features):
            features = [[row] for row in features]  # Chuyển thành danh sách 2D nếu là danh sách 1D
    else:
        raise TypeError("features phải là list hoặc numpy.ndarray")
    
    assert len(file_names) == len(features), "Số file ảnh không khớp với số dòng trong features"
    
    # Tạo DataFrame
    df = pd.DataFrame(features, columns=[col_feature])
    df.insert(0, col_time, file_names)
    
    return df

# %% [markdown]
# # Đọc và xử lý dữ liệu số

# %%
def read_data_number(data_path, time_col="thoi_gian"):
    # Đọc dữ liệu từ file CSV
    data = pd.read_csv(data_path)
    
    # Chuyển đổi cột thời gian sang kiểu datetime và đặt làm index
    data[time_col] = pd.to_datetime(data[time_col])
    data.set_index(time_col, inplace=True)
    
    # Tái lấy mẫu và tính toán thống kê
    y_t = data[['Mực nước hồ (m)', 'Lưu lượng đến hồ (m³/s)']].resample("D").mean()
    
    return y_t

# %%
def create_dataframe(y_t, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2"):
    df = pd.DataFrame({time_col: y_t.index, 
                       value_col_1: y_t['Mực nước hồ (m)'].values, 
                       value_col_2: y_t['Lưu lượng đến hồ (m³/s)'].values})
    return df

# %% [markdown]
# # Kết hợp đặc trưng dữ liệu

# %% [markdown]
# ### Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu số gốc

# %%
def rescale_features(df, col="f_t", new_min=0, new_max=1):
    # Tạo một bản sao của DataFrame để không thay đổi dữ liệu gốc
    df_rescaled = df.copy()
    
    # Lấy dữ liệu của cột cần chuẩn hóa
    col_data = df[col]
    old_min = col_data.min()
    old_max = col_data.max()

    # Kiểm tra tránh chia cho 0 nếu tất cả giá trị giống nhau
    if old_min == old_max:
        df_rescaled[col] = new_min
    else:
        df_rescaled[col] = new_min + (col_data - old_min) * (new_max - new_min) / (old_max - old_min)

    return df_rescaled

# %% [markdown]
# ### Xác định điểm bất thường

# %%
def adjust_y_t(y_t, f_t, alpha):
    mean_y = y_t.mean()
    std_y = y_t.std()

    # Khoảng tin cậy 99,9% dựa trên trung bình và sai số chuẩn
    a = mean_y - alpha * (std_y / np.sqrt(len(y_t)))
    b = mean_y + alpha * (std_y / np.sqrt(len(y_t)))

    # Áp dụng điều chỉnh dựa trên điều kiện
    adjusted_y = np.where(
        (y_t >= a) & (y_t <= b), mean_y, np.where(y_t > b, ((y_t * f_t + mean_y) / (f_t)), ((y_t * f_t) / (1 + f_t)) )
    )

    return pd.Series(adjusted_y, index=y_t.index)

# %% [markdown]
# ### Tính biến ngoại sinh X_t

# %%
def cal_exogenous_variable(y_t, f_t, alpha, time_col="thoi_gian", y_value_col="y_t_1", filename_col="filename", f_t_col="f_t",
                             year_month_col="year_month", f_t_value_col="f_t_value", X_t_col="X_t"):
    # Kiểm tra các cột cần thiết
    required_y_t_cols = {time_col, y_value_col}
    required_f_t_cols = {filename_col, f_t_col}
    if not required_y_t_cols.issubset(y_t.columns):
        raise ValueError(f"DataFrame y_t cần chứa các cột: {required_y_t_cols}")
    if not required_f_t_cols.issubset(f_t.columns):
        raise ValueError(f"DataFrame f_t cần chứa các cột: {required_f_t_cols}")
    
    # Đảm bảo không thay đổi dữ liệu gốc
    y_t = y_t.copy()
    f_t = f_t.copy()
    
    # Chuyển đổi cột thời gian sang kiểu datetime và tạo cột year_month
    y_t[time_col] = pd.to_datetime(y_t[time_col])
    y_t[year_month_col] = y_t[time_col].dt.strftime("%Y-%m")
    
    # Chuẩn hóa tên file trong f_t và tạo cột year_month
    f_t[year_month_col] = (
        f_t[filename_col]
        .str.replace(".jpg", "", regex=True)
        .str.replace("_", "-", regex=False)
    )
    
    # Tạo từ điển ánh xạ: year_month -> f_t
    mapping = f_t.set_index(year_month_col)[f_t_col].to_dict()
    
    # Ánh xạ giá trị f_t tương ứng vào y_t; nếu không có giá trị tương ứng, gán mặc định 1.0
    y_t[f_t_value_col] = y_t[year_month_col].map(mapping).fillna(1.0)
    
    # Điều chỉnh y_t thành X_t sử dụng hàm adjust_y_t (hàm này cần được định nghĩa)
    y_t[X_t_col] = adjust_y_t(y_t[y_value_col], y_t[f_t_value_col], alpha)
    # y_t[X_t_col] = general_transition(y_t[y_value_col], y_t[f_t_value_col], alpha, delta=0.5)
    
    return y_t[[time_col, X_t_col]]

# %%
def plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_t
    mean_yt = y_t[y_col].mean()
    std_yt = y_t[y_col].std()

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_t)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_t)))

    # Tạo figure với kích thước đã cho
    plt.figure(figsize=(10, 6))
    
    # Vẽ giá trị X_t dưới dạng scatter
    plt.scatter(X_t[time_col], X_t[x_col], color='blue', label=x_col, s=20)
    
    # Vẽ giá trị y_t dưới dạng đường line
    plt.plot(X_t[time_col], y_t[y_col], color='red', label=y_col, linewidth=2)
    
    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(X_t[time_col], ci_lower, ci_upper,
                     color='gray', alpha=0.3, label='99.9% CI')
    
    # Cấu hình biểu đồ
    plt.title(f"Biểu đồ của {x_col} và {y_col} theo thời gian với khoảng tin cậy 99.9%")
    plt.xlabel("Thời gian")
    plt.ylabel("Giá trị")
    plt.legend(loc='upper left')
    plt.grid(True)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Áp dụng LSTM để dự đoán

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
def create_dataset(X: pd.DataFrame, y: pd.DataFrame, n_steps: int):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X.iloc[i : i + n_steps].values)        # lấy n_steps dòng liên tiếp
        ys.append(y.iloc[i + n_steps].values)            # lấy giá trị ở dòng i+n_steps
    return np.array(Xs), np.array(ys).reshape(-1, 1)      # reshape cho y thành (samples, 1)

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuẩn hóa dữ liệu
def split_train_test(X_data, y_data):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.85)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_test, y_test = X_data[train_length:], y_data[train_length:]

    print("Kích thước X_train:", X_train.shape)
    print("Kích thước X_test:", X_test.shape)
    print("Kích thước y_train:", y_train.shape)
    print("Kích thước y_test:", y_test.shape)

    return X_train, y_train, X_test, y_test

# %%
import numpy as np
from sklearn.model_selection import KFold

def split_data(X_data, y_data, n_splits=5, random_state=42):
    # 1) Large folds trên dữ liệu gốc
    kf_large = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    large_folds = [test_idx for _, test_idx in kf_large.split(X_data)]

    # 2) Với mỗi large fold, chia thành small folds
    small_folds = []  # small_folds[i] = list length n_splits, mỗi phần là chỉ số gốc
    for large_idx in large_folds:
        X_large = X_data[large_idx]
        kf_small = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
        small_idx_list = []
        for _, small_idx in kf_small.split(X_large):
            # small_idx là chỉ số relative trong X_large, chuyển về chỉ số gốc
            small_idx_list.append(large_idx[small_idx])
        small_folds.append(small_idx_list)

    # 3) Tạo các split train/val
    splits = []
    for k in range(n_splits):
        # val: small fold k của mỗi large fold
        val_idx = np.concatenate([small_folds[i][k] for i in range(n_splits)], axis=0)
        # train: tất cả small fold j != k
        train_idx = np.concatenate(
            [small_folds[i][j]
             for i in range(n_splits)
             for j in range(n_splits) if j != k],
            axis=0
        )

        X_train, y_train = X_data[train_idx], y_data[train_idx]
        X_val,   y_val   = X_data[val_idx],   y_data[val_idx]
        splits.append((X_train, y_train, X_val, y_val))

    return splits

# %% [markdown]
# ### Xây dựng mô hình LSTM

# %%
def build_forecast_model(time_steps, features, lstm_units=[64, 32], dropout_rate=0.3):
    inp = Input(shape=(time_steps, features))
    
    # Bi-directional Encoder
    x = GRU(lstm_units[0], return_sequences=True, activation='tanh')(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    x = GRU(lstm_units[1], return_sequences=True, activation='tanh')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    # Pooling để gom thông tin cả chuỗi
    x = GlobalAveragePooling1D()(x)
    
    # Dense layers
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    # Output scalar
    out = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inp, outputs=out)
    return model

# %%
def train_model(X_train, y_train, X_val, y_val, epochs=100, batch_size=32, save_best_model='best_model.h5', initial_lr=1e-3):
    tf.keras.backend.clear_session()

    time_steps, features = X_train.shape[1], X_train.shape[2]
    model = build_forecast_model(time_steps, features)

    # Compile với optimizer và loss phù hợp cho hồi quy
    optimizer = Adam(learning_rate=initial_lr)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Callbacks: lưu model tốt nhất, dừng sớm, giảm lr khi plateau
    checkpoint = ModelCheckpoint(save_best_model, monitor='val_loss',save_best_only=True, mode='min', verbose=1)
    
    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[checkpoint],
                        verbose=2)

    # Nạp lại weights tốt nhất trước khi return
    model.load_weights(save_best_model)
    return model, history

# %% [markdown]
# ### Đánh giá mô hình

# %%
# Xác định điểm bất thường
def evaluate_outside_confidence(y_test, y_true, alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_test
    mean_yt = np.mean(y_test)
    std_yt = np.std(y_test, ddof=1)  # ddof=1 để tính std của mẫu

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_test)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_test)))

    # Xác định các index mà y_test nằm ngoài khoảng tin cậy
    outside_ci_indices = np.where((y_test < ci_lower) | (y_test > ci_upper))[0]

    # Truy xuất dữ liệu đúng cách
    y_t_outside = y_test[outside_ci_indices]
    y_true_outside = y_true[outside_ci_indices]

    return y_t_outside, y_true_outside

# %%
def evaluate_metrics(y_true, y_pred):
    # Chuyển về numpy array 1D để mọi phép tính sum đều cho ra scalar
    y_true_arr = np.ravel(y_true)
    y_pred_arr = np.ravel(y_pred)

    mae = round(mean_absolute_error(y_true_arr, y_pred_arr), 6)
    mse = round(mean_squared_error(y_true_arr, y_pred_arr), 6)
    rmse = round(np.sqrt(mse), 6)
    
    # Tính sai số dự báo
    errors = y_true_arr - y_pred_arr
    
    # Tracking Signal: TS = Tổng sai số dự báo tích lũy / Tổng độ lệch tuyệt đối của sai số
    tracking_signal = np.sum(errors) / np.sum(np.abs(errors))
    tracking_signal = round(tracking_signal, 6)
    
    # NSE (Nash–Sutcliffe Efficiency):
    # NSE = 1 - [ sum((y_true - y_pred)^2) / sum((y_true - mean(y_true))^2 ) ]
    numerator   = np.sum((y_true_arr - y_pred_arr) ** 2)
    denominator = np.sum((y_true_arr - np.mean(y_true_arr)) ** 2)
    
    # Sau khi ravel, denominator là float; chỉ cần so sánh bình thường
    if denominator == 0:
        nse = np.nan
    else:
        nse = 1 - numerator / denominator
        nse = round(nse, 6)
    
    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "Tracking Signal": tracking_signal,
        "NSE": nse
    }

# %% [markdown]
# ### Dự báo và trực quan

# %%
# Trực quan hóa dữ liệu dự báo không dùng index
def plot_forecast(y_true, y_pred, title="Lake level forecast", alpha=3.291):
    # Tính trung bình và độ lệch chuẩn của y_true
    mean_yt = np.mean(y_true)
    std_yt = np.std(y_true, ddof=1)

    # Tính khoảng tin cậy 99.9%
    ci_lower = mean_yt - alpha * (std_yt / np.sqrt(len(y_true)))
    ci_upper = mean_yt + alpha * (std_yt / np.sqrt(len(y_true)))

    # Tạo trục x là các chỉ mục tuần tự
    x = np.arange(len(y_true))

    # Vẽ biểu đồ
    plt.figure(figsize=(10, 5))

    # Vẽ dữ liệu thực tế
    plt.plot(x, y_true, label="Actual value", color="blue", linestyle='-', alpha=0.7)

    # Vẽ dự báo
    plt.plot(x, y_pred, label="Predicted value", color="red", linestyle='--', alpha=0.7)

    # Vẽ vùng khoảng tin cậy 99.9%
    plt.fill_between(x, ci_lower, ci_upper, color='gray', alpha=0.3, label='99.9% CI')

    # Thiết lập tiêu đề và nhãn
    plt.title(title)
    plt.xlabel("Time Steps")
    plt.ylabel("Water Level (m)")
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.5)
    
    # Hiển thị biểu đồ
    plt.show()

# %% [markdown]
# # Thực hiện từng phần

# %% [markdown]
# ### Tiền xử lý dữ liệu ảnh

# %%
# Đọc dữ liệu ảnh và trích xuất HOG
folder_img = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\masks"
features = process_image_folder(folder_img)

# Đưa vector đặc trưng về giá trị
f_t_features = reduce_features_to_scalar(features)
f_t = create_feature_dataframe(folder_img, f_t_features, col_time='filename', col_feature='f_t')

# %% [markdown]
# ### Tiền xử lý dữ liệu số

# %%
# Đọc dữ liệu đầu vào
path_data = r"E:\AIRC_NCS_Research\CoChau\DTAA_2025_Fusion_Data\DataSetKaNak\KaNak.csv"
data = read_data_number(path_data, time_col="thoi_gian")

# Tạo DataFrame chứa thời gian và mực nước
y_t = create_dataframe(data, time_col="thoi_gian", value_col_1="y_t_1", value_col_2="y_t_2")
y_t.head()
# Out:
#    thoi_gian       y_t_1      y_t_2
# 0 2019-01-01  490.139583  28.558333
# 1 2019-01-02  490.497500  21.766667
# 2 2019-01-03  490.781667  13.733333
# 3 2019-01-04  490.941667  11.275000
# 4 2019-01-05  491.097917  11.250000

# %% [markdown]
# ### Chuẩn hóa khoảng và kết hợp đặc trưng

# %%
# Chuẩn hóa đặc trưng ảnh về khoảng dữ liệu mực nước gốc
f_t = rescale_features(f_t, col="f_t", new_min=y_t['y_t_1'].min(), new_max=y_t['y_t_1'].max())

# %%
# Tính X_t
alpha = 3.291 # 99.9%
X_t = cal_exogenous_variable(y_t, f_t, alpha)

# Trực quan X_t
# plot_with_confidence_interval(X_t, y_t, time_col="thoi_gian", x_col="X_t", y_col="y_t_1", alpha=alpha)

# %% [markdown]
# ### Chia dữ liệu

# %%
# Chuyển 'thoi_gian' về datetime để đảm bảo kiểu dữ liệu đúng
X_t["thoi_gian"] = pd.to_datetime(X_t["thoi_gian"])
y_t["thoi_gian"] = pd.to_datetime(y_t["thoi_gian"])

# Gộp hai DataFrame theo 'thoi_gian'
df_ts = pd.merge(y_t[["thoi_gian", "y_t_1", "y_t_2"]], X_t[["thoi_gian", "X_t"]], on="thoi_gian", how="inner")
df_ts.set_index("thoi_gian", inplace=True)

# %%
# Chuẩn hóa dữ liệu
def scaler_data(X, y):
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    return scaler_X, scaler_y, X, y

# %%
time_steps = 7

# Tạo chuỗi dữ liệu
X_test, y_test = create_dataset(df_ts[['X_t', 'y_t_1', 'y_t_2']], df_ts[['y_t_1']], time_steps)
print(X_test.shape, y_test.shape)
# Out:
# (1454, 7, 3) (1454, 1)

# %%
time_steps = 7

# Tạo chuỗi dữ liệu
X_data, y_data = create_dataset(df_ts[['X_t', 'y_t_1', 'y_t_2']], df_ts[['y_t_1']], time_steps)

# Chia dữ liệu
X_train_val, y_train_val, X_test, y_test = split_train_test(X_data, y_data)

# Chia K-Fold
splits = split_data(X_train_val, y_train_val)
# Out:
# Kích thước X_train: (1235, 7, 3)
# Kích thước X_test: (219, 7, 3)
# Kích thước y_train: (1235, 1)
# Kích thước y_test: (219, 1)

# %%
# for i in range(5):
#     print(f"—— Fold {i+1} ——")

#     # 4) Tải lại weights tốt nhất
#     model = load_model(f'./BestModel/KFold_HOG_GRU_Fusion_{i+1}.hdf5')

#     # 6) Dự đoán trên tập X_test đã scale
#     y_pred = model.predict(X_test)

#     # 8) Đánh giá metric trên giá trị gốc
#     print()
#     print(f"Kết quả Fold {i+1}")
#     print(evaluate_metrics(y_test, y_pred))

#     # 10) Lấy điểm bất thường và đánh giá tiếp
#     y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)
#     print(evaluate_metrics(y_true_out, y_t_out))

#     # # 9) Vẽ đồ thị forecast
#     # plot_forecast(y_test, y_pred)

# %% [markdown]
# ### Huấn luyện ARIMA

# %%
rest_time = 30
for i in range(5):
    print(f"—— Fold {i+1} ——")

    # 1) Clear session để release graph cũ
    tf.keras.backend.clear_session()

    # 2) Fit scaler chỉ trên X_train và y_train của fold
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_tr = splits[i][0]
    y_tr = splits[i][1]
    X_vl = splits[i][2]
    y_vl = splits[i][3]

    # reshape nếu cần: X có shape (n_samples, time_steps, n_feat) -> flatten để scaler
    n_samples_tr, ts, n_feat = X_tr.shape
    X_tr_flat = X_tr.reshape(-1, n_feat)
    X_vl_flat = X_vl.reshape(-1, n_feat)

    X_tr_s = scaler_X.fit_transform(X_tr_flat).reshape(n_samples_tr, ts, n_feat)
    X_vl_s = scaler_X.transform(X_vl_flat).reshape(X_vl.shape)

    y_tr_s = scaler_y.fit_transform(y_tr.reshape(-1, 1))
    y_vl_s = scaler_y.transform(y_vl.reshape(-1, 1))

    # 3) Train và lưu model tốt nhất của fold
    model, history = train_model(
        X_tr_s, y_tr_s,
        X_vl_s, y_vl_s,
        epochs=100,
        batch_size=16,
        save_best_model=f'./BestModel/KFold_HOG_GRU_Fusion_{i+1}_KN.hdf5',
        initial_lr=1e-3
    )

    # 4) Tải lại weights tốt nhất
    model = load_model(f'./BestModel/KFold_HOG_GRU_Fusion_{i+1}_KN.hdf5')

    # 5) Transform X_test (giữ nguyên y_test gốc)
    X_test = X_test  # shape (n_samples_test, ts, n_feat)
    n_samples_test = X_test.shape[0]
    X_test_flat = X_test.reshape(-1, n_feat)
    X_test_s = scaler_X.transform(X_test_flat).reshape(n_samples_test, ts, n_feat)

    # 6) Dự đoán trên tập X_test đã scale
    y_pred_s = model.predict(X_test_s)

    # 7) Inverse scale để về giá trị gốc
    y_pred = scaler_y.inverse_transform(y_pred_s).reshape(-1, 1)

    # 8) Đánh giá metric trên giá trị gốc
    print()
    print(f"Kết quả Fold {i+1}")
    print(evaluate_metrics(y_test, y_pred))

    # 10) Lấy điểm bất thường và đánh giá tiếp
    y_t_out, y_true_out = evaluate_outside_confidence(y_test, y_pred)
    print(evaluate_metrics(y_true_out, y_t_out))

    # 9) Vẽ đồ thị forecast
    plot_forecast(y_test, y_pred)

    print(f"Kết thúc Fold {i+1}. Nghỉ {rest_time}s...\n")
# Out:
# —— Fold 1 ——
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#
# Epoch 1: val_loss improved from inf to 0.07483, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 4s - loss: 0.0452 - val_loss: 0.0748 - 4s/epoch - 64ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.07483 to 0.06346, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0215 - val_loss: 0.0635 - 405ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.06346 to 0.05052, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0213 - val_loss: 0.0505 - 400ms/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.05052 to 0.02835, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0181 - val_loss: 0.0284 - 404ms/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.02835 to 0.01140, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0153 - val_loss: 0.0114 - 427ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.01140 to 0.00950, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0201 - val_loss: 0.0095 - 414ms/epoch - 7ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.00950 to 0.00656, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0135 - val_loss: 0.0066 - 411ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.00656 to 0.00622, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0153 - val_loss: 0.0062 - 393ms/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00622 to 0.00293, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0138 - val_loss: 0.0029 - 407ms/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00293 to 0.00272, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0129 - val_loss: 0.0027 - 394ms/epoch - 6ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0129 - val_loss: 0.0039 - 342ms/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0119 - val_loss: 0.0045 - 348ms/epoch - 6ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0114 - val_loss: 0.0039 - 346ms/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0106 - val_loss: 0.0027 - 340ms/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0106 - val_loss: 0.0039 - 347ms/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00272
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0031 - 359ms/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.00272 to 0.00163, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0016 - 394ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0109 - val_loss: 0.0021 - 362ms/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0100 - val_loss: 0.0020 - 348ms/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0028 - 349ms/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0100 - val_loss: 0.0030 - 360ms/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0022 - 349ms/epoch - 6ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0025 - 350ms/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0092 - val_loss: 0.0037 - 355ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0023 - 366ms/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0019 - 350ms/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0098 - val_loss: 0.0024 - 360ms/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0018 - 350ms/epoch - 6ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0032 - 379ms/epoch - 6ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0023 - 367ms/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0018 - 364ms/epoch - 6ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0027 - 386ms/epoch - 6ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0018 - 372ms/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0024 - 360ms/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0021 - 367ms/epoch - 6ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0088 - val_loss: 0.0019 - 362ms/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0025 - 365ms/epoch - 6ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0017 - 359ms/epoch - 6ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0090 - val_loss: 0.0017 - 363ms/epoch - 6ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00163
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0033 - 347ms/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.00163 to 0.00135, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0013 - 394ms/epoch - 6ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0014 - 356ms/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0026 - 350ms/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0021 - 362ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0022 - 368ms/epoch - 6ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0041 - 396ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0021 - 351ms/epoch - 6ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0023 - 324ms/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0026 - 354ms/epoch - 6ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0019 - 353ms/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0028 - 339ms/epoch - 5ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0015 - 376ms/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00135
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0014 - 415ms/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.00135 to 0.00132, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0013 - 483ms/epoch - 8ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0018 - 378ms/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0013 - 374ms/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0018 - 371ms/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0015 - 377ms/epoch - 6ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0014 - 371ms/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0019 - 368ms/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0019 - 397ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.00132 to 0.00132, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0013 - 400ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0022 - 351ms/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0024 - 338ms/epoch - 5ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0021 - 330ms/epoch - 5ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0017 - 340ms/epoch - 5ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00132
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0019 - 328ms/epoch - 5ms/step
# Epoch 68/100
#
# Epoch 68: val_loss improved from 0.00132 to 0.00126, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0013 - 386ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00126
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0014 - 392ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00126
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0015 - 423ms/epoch - 7ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00126
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0015 - 424ms/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.00126 to 0.00122, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0012 - 459ms/epoch - 7ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0018 - 358ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0032 - 350ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0017 - 379ms/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0020 - 342ms/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0025 - 341ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0024 - 360ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0015 - 355ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0018 - 347ms/epoch - 6ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0023 - 363ms/epoch - 6ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0024 - 446ms/epoch - 7ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0015 - 394ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0012 - 381ms/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0014 - 372ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0015 - 374ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00122
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0018 - 370ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss improved from 0.00122 to 0.00111, saving model to ./BestModel\KFold_HOG_GRU_Fusion_1_KN.hdf5
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0011 - 401ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0014 - 350ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0029 - 333ms/epoch - 5ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0020 - 335ms/epoch - 5ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0015 - 397ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0018 - 380ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0016 - 438ms/epoch - 7ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0014 - 412ms/epoch - 7ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0015 - 352ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0014 - 380ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0052 - 351ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0016 - 347ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00111
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0013 - 353ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 3ms/step
#
# Kết quả Fold 1
# {'MAE': 0.451203, 'MSE': 0.299344, 'RMSE': 0.547123, 'Tracking Signal': -0.33972, 'NSE': 0.987447}
# {'MAE': 0.449268, 'MSE': 0.29873, 'RMSE': 0.546562, 'Tracking Signal': 0.346233, 'NSE': 0.98786}
# Kết thúc Fold 1. Nghỉ 30s...
#
# —— Fold 2 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.09245, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 4s - loss: 0.0434 - val_loss: 0.0924 - 4s/epoch - 59ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.09245 to 0.08788, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0879 - 384ms/epoch - 6ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.08788 to 0.07881, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0235 - val_loss: 0.0788 - 385ms/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.07881 to 0.06720, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0222 - val_loss: 0.0672 - 429ms/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.06720 to 0.04496, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0214 - val_loss: 0.0450 - 408ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.04496 to 0.02702, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0198 - val_loss: 0.0270 - 376ms/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.02702 to 0.01166, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0189 - val_loss: 0.0117 - 415ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.01166 to 0.00468, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0154 - val_loss: 0.0047 - 418ms/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00468 to 0.00340, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0166 - val_loss: 0.0034 - 420ms/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0154 - val_loss: 0.0036 - 349ms/epoch - 6ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0135 - val_loss: 0.0044 - 362ms/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0042 - 405ms/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0120 - val_loss: 0.0035 - 392ms/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0137 - val_loss: 0.0046 - 383ms/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00340
# 62/62 - 0s - loss: 0.0116 - val_loss: 0.0044 - 350ms/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.00340 to 0.00243, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0111 - val_loss: 0.0024 - 419ms/epoch - 7ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00243
# 62/62 - 0s - loss: 0.0098 - val_loss: 0.0034 - 400ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.00243 to 0.00210, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0105 - val_loss: 0.0021 - 438ms/epoch - 7ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.00210 to 0.00197, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0114 - val_loss: 0.0020 - 397ms/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00197
# 62/62 - 0s - loss: 0.0093 - val_loss: 0.0037 - 389ms/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00197
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0022 - 380ms/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00197
# 62/62 - 0s - loss: 0.0088 - val_loss: 0.0024 - 410ms/epoch - 7ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00197
# 62/62 - 0s - loss: 0.0105 - val_loss: 0.0031 - 368ms/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.00197 to 0.00171, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0093 - val_loss: 0.0017 - 388ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0025 - 349ms/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0020 - 363ms/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0023 - 358ms/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0090 - val_loss: 0.0026 - 360ms/epoch - 6ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0018 - 360ms/epoch - 6ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0019 - 362ms/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0017 - 358ms/epoch - 6ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00171
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0022 - 365ms/epoch - 6ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.00171 to 0.00136, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0014 - 428ms/epoch - 7ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00136
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0024 - 365ms/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.00136 to 0.00117, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0012 - 420ms/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0018 - 375ms/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.00117 to 0.00112, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0011 - 442ms/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00112
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0013 - 375ms/epoch - 6ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00112
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0015 - 336ms/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00112
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0022 - 351ms/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.00112
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0017 - 351ms/epoch - 6ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00112
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0034 - 339ms/epoch - 5ms/step
# Epoch 43/100
#
# Epoch 43: val_loss improved from 0.00112 to 0.00100, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0080 - val_loss: 9.9951e-04 - 392ms/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00100
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0015 - 387ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00100
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0013 - 384ms/epoch - 6ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00100
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0013 - 385ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00100
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0020 - 384ms/epoch - 6ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00100
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0015 - 423ms/epoch - 7ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.00100 to 0.00079, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0063 - val_loss: 7.8502e-04 - 469ms/epoch - 8ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00079
# 62/62 - 0s - loss: 0.0060 - val_loss: 9.0773e-04 - 364ms/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss improved from 0.00079 to 0.00071, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0075 - val_loss: 7.1037e-04 - 383ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0013 - 344ms/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0017 - 348ms/epoch - 6ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0064 - val_loss: 8.3352e-04 - 370ms/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0017 - 422ms/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0012 - 393ms/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0017 - 358ms/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0012 - 363ms/epoch - 6ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0012 - 373ms/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0059 - 358ms/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0023 - 365ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0012 - 397ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0010 - 360ms/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0014 - 375ms/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0028 - 382ms/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0070 - val_loss: 7.7519e-04 - 353ms/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0056 - val_loss: 7.8700e-04 - 359ms/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0014 - 371ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0019 - 348ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0070 - val_loss: 9.5732e-04 - 362ms/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0021 - 390ms/epoch - 6ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0070 - val_loss: 8.3132e-04 - 385ms/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0012 - 358ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0030 - 383ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0012 - 404ms/epoch - 7ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00071
# 62/62 - 0s - loss: 0.0058 - val_loss: 7.3159e-04 - 415ms/epoch - 7ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.00071 to 0.00069, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0081 - val_loss: 6.9353e-04 - 393ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss improved from 0.00069 to 0.00068, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0045 - val_loss: 6.7683e-04 - 391ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00068
# 62/62 - 0s - loss: 0.0059 - val_loss: 8.3960e-04 - 380ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00068
# 62/62 - 0s - loss: 0.0062 - val_loss: 9.6831e-04 - 433ms/epoch - 7ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00068
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0016 - 372ms/epoch - 6ms/step
# Epoch 82/100
#
# Epoch 82: val_loss improved from 0.00068 to 0.00056, saving model to ./BestModel\KFold_HOG_GRU_Fusion_2_KN.hdf5
# 62/62 - 0s - loss: 0.0053 - val_loss: 5.6221e-04 - 466ms/epoch - 8ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0064 - val_loss: 8.3903e-04 - 464ms/epoch - 7ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0010 - 466ms/epoch - 8ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0015 - 365ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0063 - val_loss: 8.3514e-04 - 354ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0077 - val_loss: 6.4990e-04 - 362ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0052 - val_loss: 7.1929e-04 - 356ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0065 - val_loss: 8.1125e-04 - 360ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0010 - 370ms/epoch - 6ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0071 - val_loss: 9.6891e-04 - 383ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0013 - 351ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0020 - 350ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0012 - 356ms/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0063 - val_loss: 9.2860e-04 - 350ms/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0027 - 342ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0011 - 350ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0056 - val_loss: 6.4163e-04 - 344ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0080 - val_loss: 0.0016 - 394ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00056
# 62/62 - 0s - loss: 0.0060 - val_loss: 9.6618e-04 - 352ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 3ms/step
#
# Kết quả Fold 2
# {'MAE': 0.795605, 'MSE': 0.86794, 'RMSE': 0.931633, 'Tracking Signal': 0.429369, 'NSE': 0.963604}
# {'MAE': 0.789947, 'MSE': 0.847261, 'RMSE': 0.920468, 'Tracking Signal': -0.403491, 'NSE': 0.972422}
# Kết thúc Fold 2. Nghỉ 30s...
#
# —— Fold 3 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.08698, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 4s - loss: 0.0345 - val_loss: 0.0870 - 4s/epoch - 59ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.08698 to 0.06622, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0223 - val_loss: 0.0662 - 410ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.06622 to 0.04866, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0201 - val_loss: 0.0487 - 435ms/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.04866 to 0.03478, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0146 - val_loss: 0.0348 - 398ms/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.03478 to 0.02983, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0124 - val_loss: 0.0298 - 420ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.02983 to 0.02049, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0146 - val_loss: 0.0205 - 415ms/epoch - 7ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.02049 to 0.01315, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0131 - val_loss: 0.0132 - 416ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.01315 to 0.00695, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0119 - val_loss: 0.0069 - 412ms/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00695 to 0.00407, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0110 - val_loss: 0.0041 - 413ms/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00407 to 0.00350, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0104 - val_loss: 0.0035 - 457ms/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0114 - val_loss: 0.0068 - 405ms/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0102 - val_loss: 0.0040 - 455ms/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0098 - val_loss: 0.0054 - 367ms/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0083 - val_loss: 0.0049 - 356ms/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0055 - 349ms/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0049 - 361ms/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0096 - val_loss: 0.0065 - 357ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0039 - 348ms/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0095 - val_loss: 0.0037 - 386ms/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.00350
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0044 - 353ms/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.00350 to 0.00322, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0085 - val_loss: 0.0032 - 402ms/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0034 - 357ms/epoch - 6ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0078 - val_loss: 0.0052 - 364ms/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0041 - 362ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0041 - 359ms/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0046 - 362ms/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00322
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0034 - 370ms/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.00322 to 0.00302, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0030 - 400ms/epoch - 6ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0059 - 355ms/epoch - 6ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0044 - 391ms/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0071 - val_loss: 0.0036 - 386ms/epoch - 6ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0035 - 373ms/epoch - 6ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0035 - 396ms/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0034 - 388ms/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0046 - 359ms/epoch - 6ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0036 - 354ms/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0038 - 343ms/epoch - 6ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0048 - 340ms/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0039 - 342ms/epoch - 6ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00302
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0044 - 388ms/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.00302 to 0.00300, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0030 - 388ms/epoch - 6ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0032 - 342ms/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0036 - 340ms/epoch - 5ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0032 - 343ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0036 - 342ms/epoch - 6ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0031 - 358ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0031 - 383ms/epoch - 6ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00300
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0034 - 368ms/epoch - 6ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.00300 to 0.00290, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0029 - 407ms/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0034 - 356ms/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0042 - 352ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0030 - 368ms/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0030 - 370ms/epoch - 6ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0033 - 365ms/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0037 - 354ms/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0044 - 354ms/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0038 - 355ms/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0031 - 380ms/epoch - 6ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00290
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0036 - 363ms/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: val_loss improved from 0.00290 to 0.00277, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0028 - 405ms/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0040 - 355ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0034 - 360ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0045 - val_loss: 0.0028 - 356ms/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0031 - 356ms/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0029 - 350ms/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0031 - 350ms/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0038 - 354ms/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0030 - 346ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0042 - val_loss: 0.0028 - 363ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0032 - 348ms/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0093 - 358ms/epoch - 6ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00277
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0034 - 360ms/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.00277 to 0.00273, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0027 - 401ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.00273 to 0.00271, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0027 - 398ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00271
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0030 - 351ms/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss improved from 0.00271 to 0.00257, saving model to ./BestModel\KFold_HOG_GRU_Fusion_3_KN.hdf5
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0026 - 388ms/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0036 - 360ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0032 - 360ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0033 - 376ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0031 - 350ms/epoch - 6ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0030 - 360ms/epoch - 6ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0031 - 352ms/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0034 - 356ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0044 - val_loss: 0.0035 - 355ms/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0032 - 354ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0039 - val_loss: 0.0030 - 360ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0058 - val_loss: 0.0036 - 376ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0032 - 356ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0048 - val_loss: 0.0033 - 352ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0050 - val_loss: 0.0026 - 351ms/epoch - 6ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0032 - 350ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0027 - 350ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0068 - val_loss: 0.0033 - 353ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0050 - 349ms/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0027 - 350ms/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0034 - 358ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0040 - val_loss: 0.0026 - 351ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0040 - 354ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0040 - 346ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00257
# 62/62 - 0s - loss: 0.0047 - val_loss: 0.0033 - 384ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 3ms/step
#
# Kết quả Fold 3
# {'MAE': 0.500913, 'MSE': 0.35775, 'RMSE': 0.598122, 'Tracking Signal': 0.131994, 'NSE': 0.984998}
# {'MAE': 0.495976, 'MSE': 0.349864, 'RMSE': 0.591493, 'Tracking Signal': -0.094881, 'NSE': 0.985347}
# Kết thúc Fold 3. Nghỉ 30s...
#
# —— Fold 4 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.08863, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 4s - loss: 0.0279 - val_loss: 0.0886 - 4s/epoch - 60ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.08863 to 0.08207, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0201 - val_loss: 0.0821 - 416ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.08207 to 0.07200, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0173 - val_loss: 0.0720 - 438ms/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.07200 to 0.06259, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0146 - val_loss: 0.0626 - 443ms/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.06259 to 0.04676, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0137 - val_loss: 0.0468 - 416ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.04676 to 0.02064, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0113 - val_loss: 0.0206 - 397ms/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.02064 to 0.00969, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0122 - val_loss: 0.0097 - 413ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.00969 to 0.00362, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0110 - val_loss: 0.0036 - 401ms/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00362 to 0.00202, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0113 - val_loss: 0.0020 - 400ms/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00202 to 0.00197, saving model to ./BestModel\KFold_HOG_GRU_Fusion_4_KN.hdf5
# 62/62 - 0s - loss: 0.0105 - val_loss: 0.0020 - 398ms/epoch - 6ms/step
# Epoch 11/100
#
# ...
# 62/62 - 0s - loss: 0.0048 - val_loss: 9.5486e-04 - 339ms/epoch - 5ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00042
# 62/62 - 0s - loss: 0.0049 - val_loss: 0.0010 - 342ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00042
# 62/62 - 0s - loss: 0.0047 - val_loss: 6.9201e-04 - 350ms/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00042
# 62/62 - 0s - loss: 0.0042 - val_loss: 0.0011 - 373ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 2ms/step
#
# Kết quả Fold 4
# {'MAE': 0.545812, 'MSE': 0.470998, 'RMSE': 0.686293, 'Tracking Signal': 0.440446, 'NSE': 0.980249}
# {'MAE': 0.549127, 'MSE': 0.47838, 'RMSE': 0.69165, 'Tracking Signal': -0.42651, 'NSE': 0.97648}
# Kết thúc Fold 4. Nghỉ 30s...
#
# —— Fold 5 ——
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.08517, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 3s - loss: 0.0287 - val_loss: 0.0852 - 3s/epoch - 56ms/step
# Epoch 2/100
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.08517 to 0.07747, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0221 - val_loss: 0.0775 - 406ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.07747 to 0.06573, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0164 - val_loss: 0.0657 - 398ms/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.06573 to 0.04468, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0161 - val_loss: 0.0447 - 383ms/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.04468 to 0.01851, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0155 - val_loss: 0.0185 - 405ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.01851 to 0.01315, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0138 - val_loss: 0.0132 - 418ms/epoch - 7ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.01315 to 0.00566, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0160 - val_loss: 0.0057 - 432ms/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.00566 to 0.00539, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0141 - val_loss: 0.0054 - 394ms/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00539 to 0.00314, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0117 - val_loss: 0.0031 - 380ms/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.00314 to 0.00311, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0113 - val_loss: 0.0031 - 403ms/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.00311
# 62/62 - 0s - loss: 0.0117 - val_loss: 0.0035 - 385ms/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.00311
# 62/62 - 0s - loss: 0.0100 - val_loss: 0.0055 - 343ms/epoch - 6ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.00311 to 0.00150, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0094 - val_loss: 0.0015 - 386ms/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0021 - 352ms/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0093 - val_loss: 0.0018 - 349ms/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0103 - val_loss: 0.0043 - 371ms/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0099 - val_loss: 0.0026 - 353ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0101 - val_loss: 0.0039 - 342ms/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00150
# 62/62 - 0s - loss: 0.0082 - val_loss: 0.0035 - 358ms/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.00150 to 0.00137, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0095 - val_loss: 0.0014 - 390ms/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00137
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0027 - 349ms/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00137
# 62/62 - 0s - loss: 0.0089 - val_loss: 0.0014 - 386ms/epoch - 6ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00137
# 62/62 - 0s - loss: 0.0098 - val_loss: 0.0026 - 348ms/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00137
# 62/62 - 0s - loss: 0.0081 - val_loss: 0.0032 - 355ms/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.00137 to 0.00117, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0090 - val_loss: 0.0012 - 422ms/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0077 - val_loss: 0.0014 - 375ms/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0013 - 356ms/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0091 - val_loss: 0.0019 - 344ms/epoch - 6ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0097 - val_loss: 0.0022 - 341ms/epoch - 6ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00117
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0015 - 350ms/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.00117 to 0.00106, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0011 - 401ms/epoch - 6ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0011 - 347ms/epoch - 6ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0025 - 347ms/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0015 - 342ms/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0018 - 345ms/epoch - 6ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0084 - val_loss: 0.0019 - 345ms/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0014 - 347ms/epoch - 6ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0016 - 372ms/epoch - 6ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0015 - 346ms/epoch - 6ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00106
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0012 - 347ms/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.00106 to 0.00101, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0010 - 393ms/epoch - 6ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0087 - val_loss: 0.0014 - 355ms/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0086 - val_loss: 0.0019 - 341ms/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0082 - val_loss: 0.0012 - 359ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0012 - 341ms/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0017 - 344ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0013 - 340ms/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0072 - val_loss: 0.0011 - 346ms/epoch - 6ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0075 - val_loss: 0.0019 - 413ms/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00101
# 62/62 - 0s - loss: 0.0076 - val_loss: 0.0013 - 348ms/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss improved from 0.00101 to 0.00098, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0071 - val_loss: 9.8211e-04 - 390ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.00098
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0012 - 350ms/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00098
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0010 - 340ms/epoch - 5ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.00098 to 0.00094, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0070 - val_loss: 9.4126e-04 - 374ms/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0070 - val_loss: 0.0021 - 343ms/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0079 - val_loss: 0.0012 - 380ms/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0074 - val_loss: 0.0030 - 347ms/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0010 - 339ms/epoch - 5ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0046 - val_loss: 0.0012 - 345ms/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0014 - 347ms/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0012 - 349ms/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0012 - 348ms/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0062 - val_loss: 9.8042e-04 - 349ms/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0022 - 350ms/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0073 - val_loss: 0.0028 - 375ms/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0062 - val_loss: 0.0034 - 342ms/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0064 - val_loss: 0.0013 - 352ms/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00094
# 62/62 - 0s - loss: 0.0066 - val_loss: 0.0011 - 349ms/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss improved from 0.00094 to 0.00093, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0059 - val_loss: 9.2509e-04 - 400ms/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0011 - 372ms/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0063 - val_loss: 0.0011 - 357ms/epoch - 6ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0069 - val_loss: 0.0013 - 379ms/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0011 - 394ms/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0055 - val_loss: 0.0011 - 358ms/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0074 - val_loss: 9.7797e-04 - 342ms/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00093
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0016 - 350ms/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.00093 to 0.00073, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0056 - val_loss: 7.2968e-04 - 380ms/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0067 - val_loss: 0.0016 - 347ms/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0065 - val_loss: 0.0015 - 347ms/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0015 - 340ms/epoch - 5ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0017 - 358ms/epoch - 6ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0053 - val_loss: 7.8306e-04 - 341ms/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0061 - val_loss: 8.5974e-04 - 353ms/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0057 - val_loss: 0.0012 - 355ms/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0064 - val_loss: 9.1880e-04 - 346ms/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0010 - 345ms/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0054 - val_loss: 0.0012 - 352ms/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0056 - val_loss: 0.0013 - 347ms/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00073
# 62/62 - 0s - loss: 0.0048 - val_loss: 8.1454e-04 - 360ms/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: val_loss improved from 0.00073 to 0.00070, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0047 - val_loss: 7.0410e-04 - 414ms/epoch - 7ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0053 - val_loss: 0.0011 - 349ms/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0052 - val_loss: 0.0015 - 373ms/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0025 - 352ms/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0015 - 347ms/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0051 - val_loss: 0.0013 - 346ms/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00070
# 62/62 - 0s - loss: 0.0061 - val_loss: 0.0017 - 343ms/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: val_loss improved from 0.00070 to 0.00063, saving model to ./BestModel\KFold_HOG_GRU_Fusion_5_KN.hdf5
# 62/62 - 0s - loss: 0.0046 - val_loss: 6.3378e-04 - 386ms/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0060 - val_loss: 0.0024 - 353ms/epoch - 6ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0049 - val_loss: 8.8011e-04 - 340ms/epoch - 5ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00063
# 62/62 - 0s - loss: 0.0043 - val_loss: 0.0011 - 354ms/epoch - 6ms/step
# 7/7 [==============================] - 0s 3ms/step
#
# Kết quả Fold 5
# {'MAE': 0.543836, 'MSE': 0.410794, 'RMSE': 0.640932, 'Tracking Signal': 0.327731, 'NSE': 0.982774}
# {'MAE': 0.536315, 'MSE': 0.395507, 'RMSE': 0.628893, 'Tracking Signal': -0.299185, 'NSE': 0.984973}
# Kết thúc Fold 5. Nghỉ 30s...

# %%
rest_time = 30
for i in range(5):
    print(f"—— Fold {i+1} ——")

    # 1) Clear session để release graph cũ
    tf.keras.backend.clear_session()

    # 2) Chuẩn bị scaler trên X_train, y_train của fold
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_tr, y_tr, _, _ = splits[i]

    # Lấy shape để reshape
    n_samples_tr, ts, n_feat = X_tr.shape

    # Fit scaler_X trên X_tr
    X_tr_flat = X_tr.reshape(-1, n_feat)
    scaler_X.fit(X_tr_flat)

    # Fit scaler_y trên y_tr
    y_tr_flat = y_tr.reshape(-1, 1)
    scaler_y.fit(y_tr_flat)

    # 3) Load model đã train sẵn
    model = load_model(f'./BestModel/KFold_HOG_GRU_Fusion_{i+1}_KN.hdf5')

    # 4) Chuẩn hoá X_test
    n_samples_test = X_test.shape[0]
    X_test_flat    = X_test.reshape(-1, n_feat)
    X_test_s       = scaler_X.transform(X_test_flat).reshape(n_samples_test, ts, n_feat)

    # 5) Dự đoán và về giá trị gốc
    y_pred_s = model.predict(X_test_s)
    y_pred   = scaler_y.inverse_transform(y_pred_s).reshape(-1, 1)
    y_true   = y_test.reshape(-1, 1)

    # 6) Tính statistics cho y_true và y_pred
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()

    mean_true = np.mean(y_true_flat)
    mean_pred = np.mean(y_pred_flat)
    std_true  = np.std(y_true_flat)
    std_pred  = np.std(y_pred_flat)
    var_true  = np.var(y_true_flat)
    var_pred  = np.var(y_pred_flat)

    print("\n— Statistics (y_true vs y_pred) —")
    print(f"{'':>12} {'y_true':>12} {'y_pred':>12}")
    print(f"{'mean':>12} {mean_true:12.6f} {mean_pred:12.6f}")
    print(f"{'std':>12}  {std_true:12.6f}  {std_pred:12.6f}")
    print(f"{'var':>12}  {var_true:12.6f}  {var_pred:12.6f}\n")
# Out:
# —— Fold 1 ——
# 7/7 [==============================] - 0s 3ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.626495
#          std      4.883319      4.873614
#          var     23.846801     23.752115
#
# —— Fold 2 ——
# 7/7 [==============================] - 0s 3ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.131561
#          std      4.883319      5.447874
#          var     23.846801     29.679327
#
# —— Fold 3 ——
# 7/7 [==============================] - 0s 3ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.407104
#          std      4.883319      4.801948
#          var     23.846801     23.058704
#
# —— Fold 4 ——
# 7/7 [==============================] - 1s 2ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.232819
#          std      4.883319      4.430101
#          var     23.846801     19.625795
#
# —— Fold 5 ——
# 7/7 [==============================] - 0s 3ms/step
#
# — Statistics (y_true vs y_pred) —
#                    y_true       y_pred
#         mean   507.473208   507.294983
#          std      4.883319      5.042096
#          var     23.846801     25.422731
